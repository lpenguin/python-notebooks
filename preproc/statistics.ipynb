# %%
import sqlite3

# %%
conn = sqlite3.connect('../data/preproc/preproc.sqlite3')

# %%
query = """
select id, name, status, type, error, meta from task
"""

c = conn.cursor()
c.execute(query)

names = c.fetchall()

# %%
import pandas as pd
import numpy as np
import json
def extract_platform(name, meta):
    if 'task' in meta:
        return meta['task'].split('_')[1]
    if 'platform' in meta:
        return meta['platform']
    tokens = name.split('_')
    if len(tokens) == 2 and \
        tokens[1].startwith('GPL'):
            return tokens[1]
    return np.nan

def extract_series(name, meta):
    if 'task' in meta:
        return meta['task'].split('_')[0]
    if 'accession' in meta:
        return meta['accession']
    tokens = name.split('_')
    if len(tokens) == 2 and \
        tokens[0].startwith('GSE'):
            return tokens[0]
    return np.nan

# %%
AGILENT_PLATFORMS = ['GPL4133', 'GPL6480', 'GPL15849', 'GPL1708', 'GPL887', 'GPL4091', 'GPL9128', 'GPL7264', 'GPL11387',
             'GPL8687', 'GPL6848', 'GPL2879', 'GPL5477', 'GPL8841', 'GPL10123', 'GPL4093', 'GPL11386', 'GPL10806',
             'GPL8269', 'GPL10150', 'GPL8583', 'GPL15931', 'GPL4126', 'GPL10152', 'GPL16050', 'GPL2567', 'GPL9053',
             'GPL14550', 'GPL5325', 'GPL10808', 'GPL13691', 'GPL9075', 'GPL8736', 'GPL885', 'GPL9777', 'GPL7504',
             'GPL8693', 'GPL2873', 'GPL17077', 'GPL10734', 'GPL13953', 'GPL13607', 'GPL13685', 'GPL7015', 'GPL15560',
             'GPL18623', 'GPL10481', 'GPL16280', 'GPL8737', 'GPL11068']

# %%
FRMA_PLATFORMS = ['GPL' + str(x) for x in [
    570, 571, 96,
    1261,  # organism Mus musculus
    # 6244, getting strange errors. data in matrix
    # 6246, # no frma package (?). read.affybatch: The affy package can process data from the Gene ST 1.x series of arrays,
    # but you should consider using either the oligo or xps packages, which are specifically
    # designed for these arrays.
    # there is no package called ‘mogene10stv1frmavecs’

    # 90, # organism Saccharomyces cerevisiae
    3921,
    # 5175, # no frma package (?). read.affybatch: The affy package is not designed for this array type. 
    # Please use either the oligo or xps package.
    # 5188, getting strange errors. data in matrix
    8321  # organism Mus musculus
]]

# %%
def extract_method(platform):
    if platform in FRMA_PLATFORMS:
        return 'affymetrix'
    
    if platform in AGILENT_PLATFORMS:
        return 'agilent'
    
    return np.nan

    
data = (
    pd.DataFrame
    .from_records(names, columns=['id', 'name', 'status', 'type', 'error', 'meta'])
    .set_index('id')
    .assign(meta=lambda d: d.meta.map(json.loads))
    .assign(platform=lambda d: d['name'].combine(d['meta'], func=extract_platform))
    .assign(series=lambda d: d['name'].combine(d['meta'], func=extract_series))
    .assign(method=lambda d: d['platform'].map(extract_method))
)
print(data.shape)
data[:10]
# Out:
# (19320, 8)
#                 name status     type error  \
# id
# 1    GSE53224_GPL570   done  preproc  None
# 2    GSE53183_GPL570   done  preproc  None
# 3    GSE53157_GPL570   done  preproc  None
# 4   GSE65721_GPL5082   skip  preproc  None
# 5    GSE65721_GPL570   done  preproc  None
# 6    GSE53092_GPL570   done  preproc  None
# 7    GSE65707_GPL570   done  preproc  None
# 8    GSE53059_GPL570   done  preproc  None
# 9    GSE53046_GPL570   done  preproc  None
# 10   GSE53012_GPL570   done  preproc  None
#
#                                                  meta platform    series  \
# id
# 1   {'accession': 'GSE53224', 'platform': 'GPL570'...   GPL570  GSE53224
# 2   {'accession': 'GSE53183', 'platform': 'GPL570'...   GPL570  GSE53183
# 3   {'accession': 'GSE53157', 'platform': 'GPL570'...   GPL570  GSE53157
# 4   {'accession': 'GSE65721', 'platform': 'GPL5082...  GPL5082  GSE65721
# 5   {'accession': 'GSE65721', 'platform': 'GPL570'...   GPL570  GSE65721
# 6   {'accession': 'GSE53092', 'platform': 'GPL570'...   GPL570  GSE53092
# 7   {'accession': 'GSE65707', 'platform': 'GPL570'...   GPL570  GSE65707
# 8   {'accession': 'GSE53059', 'platform': 'GPL570'...   GPL570  GSE53059
# 9   {'accession': 'GSE53046', 'platform': 'GPL570'...   GPL570  GSE53046
# 10  {'accession': 'GSE53012', 'platform': 'GPL570'...   GPL570  GSE53012
#
#         method
# id
# 1   affymetrix
# 2   affymetrix
# 3   affymetrix
# 4          NaN
# 5   affymetrix
# 6   affymetrix
# 7   affymetrix
# 8   affymetrix
# 9   affymetrix
# 10  affymetrix

# %%
data.type.unique()
# Out:
# array(['preproc', 'convert-merge', 'manual'], dtype=object)

# %%
(
    data
    .query('method == "affymetrix"' 
           'and status == "done" and type == "convert-merge"')
    [['series', 'platform']]
    .drop_duplicates()
    .to_pickle('../data/preproc/series.converted.res1.pickle')
)

# %%
skin_age_series = [
    'GSE11622', 'GSE18098', 'GSE18876', 'GSE22396', 'GSE27949',
       'GSE27951', 'GSE34460', 'GSE34535', 'GSE34536', 'GSE35411',
       'GSE37223', 'GSE37689', 'GSE42432', 'GSE42902', 'GSE45516',
       'GSE47162', 'GSE47511', 'GSE47512', 'GSE47513', 'GSE51518',
       'GSE51519', 'GSE53424', 'GSE53425', 'GSE53426', 'GSE53431',
       'GSE54638', 'GSE55664', 'GSE57225', 'GSE58121', 'GSE62354',
       'GSE66511', 'GSE67098', 'GSE6710', 'GSE67762'
]

# %%
data[data.series.isin(skin_age_series)].query('status == "done"')
# Out:
#                           name status           type error  \
# id
# 120            GSE67098_GPL570   done        preproc  None
# 781            GSE45516_GPL570   done        preproc  None
# 1778           GSE27951_GPL570   done        preproc  None
# 1925           GSE27949_GPL570   done        preproc  None
# 4212           GSE11622_GPL570   done        preproc  None
# 5416             GSE6710_GPL96   done        preproc  None
# 12278         GSE18098_GPL2879   done        preproc  None
# 12963         GSE18098_GPL5477   done        preproc  None
# 13941  GSE67098_GPL570_convert   done  convert-merge  None
# 14527  GSE45516_GPL570_convert   done  convert-merge  None
# 15386  GSE27951_GPL570_convert   done  convert-merge  None
# 15514  GSE27949_GPL570_convert   done  convert-merge  None
# 17290  GSE11622_GPL570_convert   done  convert-merge  None
# 18500    GSE6710_GPL96_convert   done  convert-merge  None
#
#                                                     meta platform    series  \
# id
# 120    {'samples': ['GSM1638783', 'GSM1638784', 'GSM1...   GPL570  GSE67098
# 781    {'samples': ['GSM1106065', 'GSM1106066', 'GSM1...   GPL570  GSE45516
# 1778   {'samples': ['GSM691122', 'GSM691125', 'GSM691...   GPL570  GSE27951
# 1925   {'samples': ['GSM691122', 'GSM691125', 'GSM691...   GPL570  GSE27949
# 4212   {'samples': ['GSM294856', 'GSM294857', 'GSM294...   GPL570  GSE11622
# 5416   {'samples': ['GSM154768', 'GSM154769', 'GSM154...    GPL96   GSE6710
# 12278  {'samples': ['GSM452353', 'GSM452354', 'GSM452...  GPL2879  GSE18098
# 12963  {'samples': ['GSM452366', 'GSM452367', 'GSM452...  GPL5477  GSE18098
# 13941  {'samples': ['GSM1638783', 'GSM1638784', 'GSM1...   GPL570  GSE67098
# 14527  {'samples': ['GSM1106065', 'GSM1106066', 'GSM1...   GPL570  GSE45516
# 15386  {'samples': ['GSM691122', 'GSM691125', 'GSM691...   GPL570  GSE27951
# 15514  {'samples': ['GSM691122', 'GSM691125', 'GSM691...   GPL570  GSE27949
# 17290  {'samples': ['GSM294856', 'GSM294857', 'GSM294...   GPL570  GSE11622
# 18500  {'samples': ['GSM154768', 'GSM154769', 'GSM154...    GPL96   GSE6710
#
#            method
# id
# 120    affymetrix
# 781    affymetrix
# 1778   affymetrix
# 1925   affymetrix
# 4212   affymetrix
# 5416   affymetrix
# 12278     agilent
# 12963     agilent
# 13941  affymetrix
# 14527  affymetrix
# 15386  affymetrix
# 15514  affymetrix
# 17290  affymetrix
# 18500  affymetrix

# %%
import pymongo
db = pymongo.MongoClient().scraper_meta

series_accessions = data.series.dropna().unique().tolist()

samples = (
    pd.DataFrame(list(db.series.find({'accession': {'$in': series_accessions}}, {'_id': 0, 'samples': 1, 'accession': 1})))
#     .assign(samples=lambda d: d['samples'].map(len))
)
samples[:10]
# Out:
#   accession                                            samples
# 0   GSE1000  [GSM15785, GSM15786, GSM15787, GSM15788, GSM15...
# 1  GSE10000  [GSM44658, GSM44659, GSM44660, GSM44661, GSM44...
# 2  GSE10001  [GSM252722, GSM252723, GSM252724, GSM252725, G...
# 3  GSE10002  [GSM252734, GSM252735, GSM252736, GSM252737, G...
# 4  GSE10006  [GSM252799, GSM252800, GSM252801, GSM252802, G...
# 5  GSE10011  [GSM252936, GSM252937, GSM252938, GSM252939, G...
# 6  GSE10017                             [GSM253173, GSM253174]
# 7  GSE10021  [GSM253203, GSM253204, GSM253205, GSM253206, G...
# 8  GSE10024  [GSM253283, GSM253284, GSM253285, GSM253286, G...
# 9  GSE10026  [GSM252165, GSM252166, GSM252167, GSM252168, G...

# %%
data = pd.merge(data, samples, left_on='series', right_on='accession', how='left')

# %%
data[:10]
# Out:
#                name status     type error  \
# 0   GSE53224_GPL570   done  preproc  None
# 1   GSE53183_GPL570   done  preproc  None
# 2   GSE53157_GPL570   done  preproc  None
# 3  GSE65721_GPL5082   skip  preproc  None
# 4   GSE65721_GPL570   done  preproc  None
# 5   GSE53092_GPL570   done  preproc  None
# 6   GSE65707_GPL570   done  preproc  None
# 7   GSE53059_GPL570   done  preproc  None
# 8   GSE53046_GPL570   done  preproc  None
# 9   GSE53012_GPL570   done  preproc  None
#
#                                                 meta platform    series  \
# 0  {'samples': ['GSM1287918', 'GSM1287919', 'GSM1...   GPL570  GSE53224
# 1  {'samples': ['GSM1286097', 'GSM1286098', 'GSM1...   GPL570  GSE53183
# 2  {'samples': ['GSM1283115', 'GSM1283116', 'GSM1...   GPL570  GSE53157
# 3  {'samples': ['GSM1603234', 'GSM1603235', 'GSM1...  GPL5082  GSE65721
# 4  {'samples': ['GSM1603354', 'GSM1603355', 'GSM1...   GPL570  GSE65721
# 5  {'samples': ['GSM1282316', 'GSM1282317', 'GSM1...   GPL570  GSE53092
# 6  {'samples': ['GSM1603354', 'GSM1603355', 'GSM1...   GPL570  GSE65707
# 7  {'samples': ['GSM1281432', 'GSM1281433', 'GSM1...   GPL570  GSE53059
# 8  {'samples': ['GSM1281025', 'GSM1281026', 'GSM1...   GPL570  GSE53046
# 9  {'samples': ['GSM1280329', 'GSM1280330', 'GSM1...   GPL570  GSE53012
#
#        method accession                                            samples
# 0  affymetrix  GSE53224  [GSM1287918, GSM1287919, GSM1287920, GSM128792...
# 1  affymetrix  GSE53183  [GSM1286097, GSM1286098, GSM1286099, GSM128610...
# 2  affymetrix  GSE53157  [GSM1283115, GSM1283116, GSM1283117, GSM128311...
# 3         NaN  GSE65721  [GSM1603234, GSM1603235, GSM1603236, GSM160323...
# 4  affymetrix  GSE65721  [GSM1603234, GSM1603235, GSM1603236, GSM160323...
# 5  affymetrix  GSE53092   [GSM1282316, GSM1282317, GSM1282318, GSM1282319]
# 6  affymetrix  GSE65707  [GSM1603354, GSM1603355, GSM1603356, GSM160335...
# 7  affymetrix  GSE53059  [GSM1281432, GSM1281433, GSM1281434, GSM128143...
# 8  affymetrix  GSE53046  [GSM1281025, GSM1281026, GSM1281027, GSM128102...
# 9  affymetrix  GSE53012  [GSM1280329, GSM1280330, GSM1280331, GSM128033...

# %%
samples_lists = (
    data
    .query("status == 'done' and method == 'affymetrix'")
    .samples
    .dropna()
    .tolist()
)

samples_lists[:10]
samples_accessions = list({s for ss in samples_lists for s in ss})
# samples_accessions[:10]
len(samples_accessions)
# Out:
# 203771

# %%
import json
with open('../data/geo-annotation/samples-affumetrix-preprocessed.json', 'w') as f:
    json.dump(samples_accessions, f)

# %%
names_mapping = """GPL570	Affymetrix HG-U133_Plus_2
GPL1261	Affymetrix Mouse430_2
GPL96	Affymetrix HG-U133A
GPL10558	Illumina HumanHT-12 V4.0
GPL6244	Affymetrix HuGene-1_0-st
GPL6947	Illumina HumanHT-12 V3.0
GPL6246	Affymetrix MoGene-1_0-st
GPL6480	Agilent 014850
GPL1355	Affymetrix Rat230_2
GPL4133	Agilent 014850
GPL571	Affymetrix HG-U133A_2
GPL97	Affymetrix HG-U133B
GPL5175	Affymetrix HuEx-1_0-st
GPL198	Affymetrix ATH1-121501
GPL6887	Illumina MouseWG-6 v2.0
GPL6885	Illumina MouseRef-8 v2.0
GPL6884	Illumina HumanWG-6 v3.0
GPL5188	Affymetrix HuEx-1_0-st
GPL81	Affymetrix MG_U74Av2
GPL7202	Agilent-014868"""

platform_names1 = (pd.DataFrame
 .from_records([line.split("\t") for line in names_mapping.split("\n")],
                columns=['accession', 'name'])
 )

platform_names1
# [(line.split("\t")) for line in names_mapping.split("\n")]
# Out:
#    accession                       name
# 0     GPL570  Affymetrix HG-U133_Plus_2
# 1    GPL1261      Affymetrix Mouse430_2
# 2      GPL96        Affymetrix HG-U133A
# 3   GPL10558   Illumina HumanHT-12 V4.0
# 4    GPL6244   Affymetrix HuGene-1_0-st
# 5    GPL6947   Illumina HumanHT-12 V3.0
# 6    GPL6246   Affymetrix MoGene-1_0-st
# 7    GPL6480             Agilent 014850
# 8    GPL1355        Affymetrix Rat230_2
# 9    GPL4133             Agilent 014850
# 10    GPL571      Affymetrix HG-U133A_2
# 11     GPL97        Affymetrix HG-U133B
# 12   GPL5175     Affymetrix HuEx-1_0-st
# 13    GPL198     Affymetrix ATH1-121501
# 14   GPL6887    Illumina MouseWG-6 v2.0
# 15   GPL6885   Illumina MouseRef-8 v2.0
# 16   GPL6884    Illumina HumanWG-6 v3.0
# 17   GPL5188     Affymetrix HuEx-1_0-st
# 18     GPL81       Affymetrix MG_U74Av2
# 19   GPL7202             Agilent-014868

# %%
names2 = [
{"accession": "GPL887", "name": "Agilent-012097"},
{"accession": "GPL1708", "name": "Agilent-012391"},
{"accession": "GPL2879", "name": "Agilent-013282"},
{"accession": "GPL3921", "name": "Affymetrix HT_HG-U133A"},
{"accession": "GPL4091", "name": "Agilent-014693"},
{"accession": "GPL4093", "name": "Agilent-014698"},
{"accession": "GPL5477", "name": "Agilent-014950"},
{"accession": "GPL6848", "name": "Agilent-012391"},
{"accession": "GPL7264", "name": "Agilent-012097"},
{"accession": "GPL8321", "name": "Affymetrix Mouse430A_2"},
{"accession": "GPL9128", "name": "Agilent-014693"},
{"accession": "GPL10123", "name": "Agilent-022060"},
{"accession": "GPL10806", "name": "Agilent-023456"},
{"accession": "GPL11387", "name": "Agilent  180K v3.0"},
]

platform_names2 = (pd.DataFrame
 .from_records(names2,
                columns=['accession', 'name'])
 )

platform_names = pd.concat([platform_names1, platform_names2]).reset_index().drop('index', axis=1)#.drop('level_0', axis=1)
platform_names
# Out:
#    accession                       name
# 0     GPL570  Affymetrix HG-U133_Plus_2
# 1    GPL1261      Affymetrix Mouse430_2
# 2      GPL96        Affymetrix HG-U133A
# 3   GPL10558   Illumina HumanHT-12 V4.0
# 4    GPL6244   Affymetrix HuGene-1_0-st
# 5    GPL6947   Illumina HumanHT-12 V3.0
# 6    GPL6246   Affymetrix MoGene-1_0-st
# 7    GPL6480             Agilent 014850
# 8    GPL1355        Affymetrix Rat230_2
# 9    GPL4133             Agilent 014850
# 10    GPL571      Affymetrix HG-U133A_2
# 11     GPL97        Affymetrix HG-U133B
# 12   GPL5175     Affymetrix HuEx-1_0-st
# 13    GPL198     Affymetrix ATH1-121501
# 14   GPL6887    Illumina MouseWG-6 v2.0
# 15   GPL6885   Illumina MouseRef-8 v2.0
# 16   GPL6884    Illumina HumanWG-6 v3.0
# 17   GPL5188     Affymetrix HuEx-1_0-st
# 18     GPL81       Affymetrix MG_U74Av2
# 19   GPL7202             Agilent-014868
# 20    GPL887             Agilent-012097
# 21   GPL1708             Agilent-012391
# 22   GPL2879             Agilent-013282
# 23   GPL3921     Affymetrix HT_HG-U133A
# 24   GPL4091             Agilent-014693
# 25   GPL4093             Agilent-014698
# 26   GPL5477             Agilent-014950
# 27   GPL6848             Agilent-012391
# 28   GPL7264             Agilent-012097
# 29   GPL8321     Affymetrix Mouse430A_2
# 30   GPL9128             Agilent-014693
# 31  GPL10123             Agilent-022060
# 32  GPL10806             Agilent-023456
# 33  GPL11387         Agilent  180K v3.0

# %%
_t = pd.merge(
    data
    [data.method.notnull()]
    .query("status == 'done' and type == 'preproc'")
    .groupby(['platform'])
    .samples
    .sum()
    .to_frame()
    .sort('samples', ascending=False),
    platform_names,
    left_index=True,
    right_on='accession',
    how='left'
).reset_index().drop('index', axis=1)[:20]
_t[['accession', 'name', 'samples']]
# Out:
#    accession                       name  samples
# 0     GPL570  Affymetrix HG-U133_Plus_2   123491
# 1    GPL1261      Affymetrix Mouse430_2    51102
# 2      GPL96        Affymetrix HG-U133A    39525
# 3     GPL571      Affymetrix HG-U133A_2    14213
# 4    GPL8321     Affymetrix Mouse430A_2     7070
# 5    GPL6480             Agilent 014850     3892
# 6    GPL4133             Agilent 014850     3650
# 7    GPL3921     Affymetrix HT_HG-U133A     3545
# 8    GPL9128             Agilent-014693     3028
# 9    GPL4091             Agilent-014693     2974
# 10   GPL1708             Agilent-012391     1779
# 11   GPL7264             Agilent-012097     1427
# 12    GPL887             Agilent-012097     1002
# 13   GPL6848             Agilent-012391      964
# 14   GPL2879             Agilent-013282      865
# 15   GPL5477             Agilent-014950      729
# 16  GPL10123             Agilent-022060      723
# 17   GPL4093             Agilent-014698      698
# 18  GPL10806             Agilent-023456      501
# 19  GPL11387         Agilent  180K v3.0      501

# %%
unknown_platforms = pd.DataFrame(list(db.platforms.find({'accession': {'$in': _t[_t.name.isnull()].accession.tolist()}}, {'_id': 0, 'title': 1, 'accession' :1})))
unknown_platforms
# Out:
#    accession                                              title
# 0     GPL887  Agilent-012097 Human 1A Microarray (V2) G4110B...
# 1    GPL1708  Agilent-012391 Whole Human Genome Oligo Microa...
# 2    GPL2879  Agilent-013282 Human Genome CGH Microarray 44B...
# 3    GPL3921  [HT_HG-U133A] Affymetrix HT Human Genome U133A...
# 4    GPL4091  Agilent-014693 Human Genome CGH Microarray 244...
# 5    GPL4093  Agilent-014698 Human Genome CGH Microarray 105...
# 6    GPL5477  Agilent-014950 Human Genome CGH Microarray 4x4...
# 7    GPL6848  Agilent-012391 Whole Human Genome Oligo Microa...
# 8    GPL7264  Agilent-012097 Human 1A Microarray (V2) G4110B...
# 9    GPL8321  [Mouse430A_2] Affymetrix Mouse Genome 430A 2.0...
# 10   GPL9128  Agilent-014693 Human Genome CGH Microarray 244...
# 11  GPL10123  Agilent-022060 SurePrint G3 Human CGH Microarr...
# 12  GPL10806  Agilent-023456 Custom BCM-Beaudet Human 180K V...
# 13  GPL11387                Agilent Eichler Human CNP 180K v3.0

# %%
db.platforms.count()
# Out:
# 23231

# %%
', '.join(_t[_t.accession.isin(FRMA_PLATFORMS)].accession)
# Out:
# 'GPL570, GPL1261, GPL96, GPL571, GPL8321, GPL3921'

# %%
', '.join(_t[_t.accession.isin(AGILENT_PLATFORMS)].accession)
# Out:
# 'GPL6480, GPL4133, GPL9128, GPL4091, GPL1708, GPL7264, GPL887, GPL6848, GPL2879, GPL5477, GPL10123, GPL4093, GPL10806, GPL11387'

# %%
data.query('method == "agilent" and status == "done"')
# Out:
#                     name status     type error  \
# 3816    GSE26863_GPL9128   done  preproc  None
# 3929    GSE23720_GPL9128   done  preproc  None
# 4321     GSE9015_GPL4091   done  preproc  None
# 11750  GSE21468_GPL10123   done  preproc  None
# 11751  GSE23065_GPL10123   done  preproc  None
# 11753  GSE24602_GPL10123   done  preproc  None
# 11754  GSE25228_GPL10123   done  preproc  None
# 11755  GSE25411_GPL10123   done  preproc  None
# 11756  GSE26715_GPL10123   done  preproc  None
# 11757  GSE27671_GPL10123   done  preproc  None
# 11758  GSE28450_GPL10123   done  preproc  None
# 11759  GSE32414_GPL10123   done  preproc  None
# 11760  GSE34484_GPL10123   done  preproc  None
# 11761  GSE35476_GPL10123   done  preproc  None
# 11762  GSE38229_GPL10123   done  preproc  None
# 11763  GSE40299_GPL10123   done  preproc  None
# 11764  GSE41188_GPL10123   done  preproc  None
# 11765  GSE41813_GPL10123   done  preproc  None
# 11766  GSE42984_GPL10123   done  preproc  None
# 11767  GSE43810_GPL10123   done  preproc  None
# 11768  GSE44275_GPL10123   done  preproc  None
# 11769  GSE47506_GPL10123   done  preproc  None
# 11770  GSE49693_GPL10123   done  preproc  None
# 11771  GSE53070_GPL10123   done  preproc  None
# 11772  GSE54183_GPL10123   done  preproc  None
# 11773  GSE54185_GPL10123   done  preproc  None
# 11774  GSE55016_GPL10123   done  preproc  None
# 11775  GSE55345_GPL10123   done  preproc  None
# 11776  GSE55852_GPL10123   done  preproc  None
# 11777  GSE57176_GPL10123   done  preproc  None
# ...                  ...    ...      ...   ...
# 13805   GSE26849_GPL9128   done  preproc  None
# 13806   GSE27574_GPL9128   done  preproc  None
# 13807   GSE27892_GPL9128   done  preproc  None
# 13810   GSE33428_GPL9128   done  preproc  None
# 13811   GSE34979_GPL9128   done  preproc  None
# 13812   GSE35189_GPL9128   done  preproc  None
# 13813   GSE35988_GPL9128   done  preproc  None
# 13814   GSE40048_GPL9128   done  preproc  None
# 13816   GSE44271_GPL9128   done  preproc  None
# 13817   GSE47630_GPL9128   done  preproc  None
# 13818   GSE47912_GPL9128   done  preproc  None
# 13819   GSE48548_GPL9128   done  preproc  None
# 13820   GSE49808_GPL9128   done  preproc  None
# 13821   GSE50750_GPL9128   done  preproc  None
# 13822   GSE57942_GPL9128   done  preproc  None
# 13824   GSE58886_GPL9128   done  preproc  None
# 13825   GSE27965_GPL9777   done  preproc  None
# 13826   GSE28676_GPL9777   done  preproc  None
# 13827   GSE34063_GPL9777   done  preproc  None
# 13828   GSE38946_GPL9777   done  preproc  None
# 13829   GSE40299_GPL9777   done  preproc  None
# 13830   GSE41356_GPL9777   done  preproc  None
# 13831   GSE47701_GPL9777   done  preproc  None
# 13833   GSE49430_GPL9777   done  preproc  None
# 13834   GSE54328_GPL9777   done  preproc  None
# 13835   GSE55645_GPL9777   done  preproc  None
# 13836   GSE58000_GPL9777   done  preproc  None
# 13837   GSE59239_GPL9777   done  preproc  None
# 13838   GSE64462_GPL9777   done  preproc  None
# 13839   GSE66337_GPL9777   done  preproc  None
#
#                                                     meta  platform    series  \
# 3816   {'platform': 'GPL9128', 'accession': 'GSE26863...   GPL9128  GSE26863
# 3929   {'platform': 'GPL9128', 'accession': 'GSE23720...   GPL9128  GSE23720
# 4321   {'platform': 'GPL4091', 'accession': 'GSE9015'...   GPL4091   GSE9015
# 11750  {'platform': 'GPL10123', 'accession': 'GSE2146...  GPL10123  GSE21468
# 11751  {'platform': 'GPL10123', 'accession': 'GSE2306...  GPL10123  GSE23065
# 11753  {'platform': 'GPL10123', 'accession': 'GSE2460...  GPL10123  GSE24602
# 11754  {'platform': 'GPL10123', 'accession': 'GSE2522...  GPL10123  GSE25228
# 11755  {'platform': 'GPL10123', 'accession': 'GSE2541...  GPL10123  GSE25411
# 11756  {'platform': 'GPL10123', 'accession': 'GSE2671...  GPL10123  GSE26715
# 11757  {'platform': 'GPL10123', 'accession': 'GSE2767...  GPL10123  GSE27671
# 11758  {'platform': 'GPL10123', 'accession': 'GSE2845...  GPL10123  GSE28450
# 11759  {'platform': 'GPL10123', 'accession': 'GSE3241...  GPL10123  GSE32414
# 11760  {'platform': 'GPL10123', 'accession': 'GSE3448...  GPL10123  GSE34484
# 11761  {'platform': 'GPL10123', 'accession': 'GSE3547...  GPL10123  GSE35476
# 11762  {'platform': 'GPL10123', 'accession': 'GSE3822...  GPL10123  GSE38229
# 11763  {'platform': 'GPL10123', 'accession': 'GSE4029...  GPL10123  GSE40299
# 11764  {'platform': 'GPL10123', 'accession': 'GSE4118...  GPL10123  GSE41188
# 11765  {'platform': 'GPL10123', 'accession': 'GSE4181...  GPL10123  GSE41813
# 11766  {'platform': 'GPL10123', 'accession': 'GSE4298...  GPL10123  GSE42984
# 11767  {'platform': 'GPL10123', 'accession': 'GSE4381...  GPL10123  GSE43810
# 11768  {'platform': 'GPL10123', 'accession': 'GSE4427...  GPL10123  GSE44275
# 11769  {'platform': 'GPL10123', 'accession': 'GSE4750...  GPL10123  GSE47506
# 11770  {'platform': 'GPL10123', 'accession': 'GSE4969...  GPL10123  GSE49693
# 11771  {'platform': 'GPL10123', 'accession': 'GSE5307...  GPL10123  GSE53070
# 11772  {'platform': 'GPL10123', 'accession': 'GSE5418...  GPL10123  GSE54183
# 11773  {'platform': 'GPL10123', 'accession': 'GSE5418...  GPL10123  GSE54185
# 11774  {'platform': 'GPL10123', 'accession': 'GSE5501...  GPL10123  GSE55016
# 11775  {'platform': 'GPL10123', 'accession': 'GSE5534...  GPL10123  GSE55345
# 11776  {'platform': 'GPL10123', 'accession': 'GSE5585...  GPL10123  GSE55852
# 11777  {'platform': 'GPL10123', 'accession': 'GSE5717...  GPL10123  GSE57176
# ...                                                  ...       ...       ...
# 13805  {'platform': 'GPL9128', 'accession': 'GSE26849...   GPL9128  GSE26849
# 13806  {'platform': 'GPL9128', 'accession': 'GSE27574...   GPL9128  GSE27574
# 13807  {'platform': 'GPL9128', 'accession': 'GSE27892...   GPL9128  GSE27892
# 13810  {'platform': 'GPL9128', 'accession': 'GSE33428...   GPL9128  GSE33428
# 13811  {'platform': 'GPL9128', 'accession': 'GSE34979...   GPL9128  GSE34979
# 13812  {'platform': 'GPL9128', 'accession': 'GSE35189...   GPL9128  GSE35189
# 13813  {'platform': 'GPL9128', 'accession': 'GSE35988...   GPL9128  GSE35988
# 13814  {'platform': 'GPL9128', 'accession': 'GSE40048...   GPL9128  GSE40048
# 13816  {'platform': 'GPL9128', 'accession': 'GSE44271...   GPL9128  GSE44271
# 13817  {'platform': 'GPL9128', 'accession': 'GSE47630...   GPL9128  GSE47630
# 13818  {'platform': 'GPL9128', 'accession': 'GSE47912...   GPL9128  GSE47912
# 13819  {'platform': 'GPL9128', 'accession': 'GSE48548...   GPL9128  GSE48548
# 13820  {'platform': 'GPL9128', 'accession': 'GSE49808...   GPL9128  GSE49808
# 13821  {'platform': 'GPL9128', 'accession': 'GSE50750...   GPL9128  GSE50750
# 13822  {'platform': 'GPL9128', 'accession': 'GSE57942...   GPL9128  GSE57942
# 13824  {'platform': 'GPL9128', 'accession': 'GSE58886...   GPL9128  GSE58886
# 13825  {'platform': 'GPL9777', 'accession': 'GSE27965...   GPL9777  GSE27965
# 13826  {'platform': 'GPL9777', 'accession': 'GSE28676...   GPL9777  GSE28676
# 13827  {'platform': 'GPL9777', 'accession': 'GSE34063...   GPL9777  GSE34063
# 13828  {'platform': 'GPL9777', 'accession': 'GSE38946...   GPL9777  GSE38946
# 13829  {'platform': 'GPL9777', 'accession': 'GSE40299...   GPL9777  GSE40299
# 13830  {'platform': 'GPL9777', 'accession': 'GSE41356...   GPL9777  GSE41356
# 13831  {'platform': 'GPL9777', 'accession': 'GSE47701...   GPL9777  GSE47701
# 13833  {'platform': 'GPL9777', 'accession': 'GSE49430...   GPL9777  GSE49430
# 13834  {'platform': 'GPL9777', 'accession': 'GSE54328...   GPL9777  GSE54328
# 13835  {'platform': 'GPL9777', 'accession': 'GSE55645...   GPL9777  GSE55645
# 13836  {'platform': 'GPL9777', 'accession': 'GSE58000...   GPL9777  GSE58000
# 13837  {'platform': 'GPL9777', 'accession': 'GSE59239...   GPL9777  GSE59239
# 13838  {'platform': 'GPL9777', 'accession': 'GSE64462...   GPL9777  GSE64462
# 13839  {'platform': 'GPL9777', 'accession': 'GSE66337...   GPL9777  GSE66337
#
#         method accession  samples
# 3816   agilent  GSE26863      501
# 3929   agilent  GSE23720      370
# 4321   agilent   GSE9015        8
# 11750  agilent  GSE21468       74
# 11751  agilent  GSE23065        2
# 11753  agilent  GSE24602      107
# 11754  agilent  GSE25228       17
# 11755  agilent  GSE25411        1
# 11756  agilent  GSE26715        2
# 11757  agilent  GSE27671       13
# 11758  agilent  GSE28450        3
# 11759  agilent  GSE32414        8
# 11760  agilent  GSE34484        9
# 11761  agilent  GSE35476       84
# 11762  agilent  GSE38229       14
# 11763  agilent  GSE40299       23
# 11764  agilent  GSE41188       24
# 11765  agilent  GSE41813       53
# 11766  agilent  GSE42984        1
# 11767  agilent  GSE43810        4
# 11768  agilent  GSE44275        8
# 11769  agilent  GSE47506        8
# 11770  agilent  GSE49693        4
# 11771  agilent  GSE53070        4
# 11772  agilent  GSE54183       61
# 11773  agilent  GSE54185       12
# 11774  agilent  GSE55016       28
# 11775  agilent  GSE55345        6
# 11776  agilent  GSE55852       65
# 11777  agilent  GSE57176       17
# ...        ...       ...      ...
# 13805  agilent  GSE26849      254
# 13806  agilent  GSE27574       79
# 13807  agilent  GSE27892        7
# 13810  agilent  GSE33428       27
# 13811  agilent  GSE34979       10
# 13812  agilent  GSE35189      124
# 13813  agilent  GSE35988      244
# 13814  agilent  GSE40048       24
# 13816  agilent  GSE44271       27
# 13817  agilent  GSE47630       40
# 13818  agilent  GSE47912       32
# 13819  agilent  GSE48548       20
# 13820  agilent  GSE49808        5
# 13821  agilent  GSE50750        2
# 13822  agilent  GSE57942        5
# 13824  agilent  GSE58886        4
# 13825  agilent  GSE27965       46
# 13826  agilent  GSE28676        2
# 13827  agilent  GSE34063       17
# 13828  agilent  GSE38946       33
# 13829  agilent  GSE40299       23
# 13830  agilent  GSE41356        7
# 13831  agilent  GSE47701        2
# 13833  agilent  GSE49430        4
# 13834  agilent  GSE54328        4
# 13835  agilent  GSE55645       49
# 13836  agilent  GSE58000       18
# 13837  agilent  GSE59239       14
# 13838  agilent  GSE64462       31
# 13839  agilent  GSE66337        6
#
# [826 rows x 10 columns]

# %%
data.query("type == 'preproc' and status == 'done'").shape[0]
# Out:
# 9316

# %%
data.query("type == 'preproc' and status == 'done'").samples.sum()
# Out:
# 270053.0
