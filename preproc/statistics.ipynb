# %%
import sqlite3

# %%
conn = sqlite3.connect('/Users/nikita/Data/snapshots/sqlite/preproc/preproc.sqlite3')

# %%
query = """
select id, name, status, type, error from task
"""

c = conn.cursor()
c.execute(query)

names = c.fetchall()

# %%
import pandas as pd
data = pd.DataFrame.from_records(names, columns=['id', 'name', 'status', 'type', 'error'])

# %%
data['platform'] = data['name'].str.split('_').str.get(1)

# %%
data
# Out:
#           id                         name status     type        error  \
# 0          1              GSE53224_GPL570   done  preproc         None
# 1          2              GSE53183_GPL570   done  preproc         None
# 2          3              GSE53157_GPL570   done  preproc         None
# 3          4             GSE65721_GPL5082   skip  preproc         None
# 4          5              GSE65721_GPL570   done  preproc         None
# 5          6              GSE53092_GPL570   done  preproc         None
# 6          7              GSE65707_GPL570   done  preproc         None
# 7          8              GSE53059_GPL570   done  preproc         None
# 8          9              GSE53046_GPL570   done  preproc         None
# 9         10              GSE53012_GPL570   done  preproc         None
# 10        11            GSE52980_GPL11154   skip  preproc         None
# 11        12            GSE52980_GPL13534   skip  preproc         None
# ...

# %%
query = """
insert into task_platform (task_id, platform)
values(?, ?)
"""

c = conn.cursor()

# c.executemany(query, data[['id', 'platform']].to_records(index=False))

# %%
for rec in data[['id', 'platform']].to_records(index=False):
    c.execute(query, rec)

# %%
conn.close()

# %%
counts = data[data['type'] == 'preproc'].groupby(['platform', 'status']).count()[['id']].reset_index().pivot(index='platform', columns='status', values='id')
del counts['0']
counts.fillna(0, inplace=True)
import qgrid

qgrid.show_grid(counts)
# Out:
# <script type="text/javascript">
# if ($("#dg-css").length == 0){
#     $("head").append([
#         "<link href='/nbextensions/qgridjs/lib/slick.grid.css' rel='stylesheet'>",
#         "<link href='/nbextensions/qgridjs/lib/slick-default-theme.css' rel='stylesheet'>",
#         "<link href='http://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.10.4/css/jquery-ui.min.css' rel='stylesheet'>",
#         "<link id='dg-css' href='/nbextensions/qgridjs/qgrid.css' rel='stylesheet'>"
#     ]);
# }
# </script>
# <div class='q-grid-container'>
# <div id='72d6beac-082a-4b49-9b42-4c8b0c889a73' class='q-grid'></div>
# </div>

# %%
import pymongo
db = pymongo.MongoClient().scraper_meta

platforms = pd.DataFrame(list(db.platforms.find({}, {'accession': 1, 'manufacturer': 1, '_id': 0})))
platforms
# Out:
#         accession manufacturer
# 0            GPL7         None
# 1            GPL6         None
# 2            GPL8         None
# 3           GPL10         None
# 4            GPL9         None
# 5            GPL4         None
# 6           GPL11         None
# 7           GPL12         None
# 8           GPL13         None
# 9           GPL14         None
# 10           GPL5         None
# 11          GPL15         None
# 12          GPL16         None
# 13          GPL17         None
# 14          GPL18         None
# 15          GPL20         None
# 16          GPL23         None
# 17          GPL25         None
# 18          GPL24         None
# 19          GPL28         None
# 20          GPL32   Affymetrix
# 21          GPL33   Affymetrix
# 22          GPL34   Affymetrix
# 23          GPL49         None
# 24          GPL44         None
# 25          GPL52         None
# 26          GPL53         None
# 27          GPL54         None
# 28          GPL55         None
# ...

# %%
platforms_counts = pd.merge(counts, platforms, left_index=True, right_on='accession').set_index('accession')
qgrid.show_grid(platforms_counts)
# platforms_counts.columns
# Out:
# <script type="text/javascript">
# if ($("#dg-css").length == 0){
#     $("head").append([
#         "<link href='/nbextensions/qgridjs/lib/slick.grid.css' rel='stylesheet'>",
#         "<link href='/nbextensions/qgridjs/lib/slick-default-theme.css' rel='stylesheet'>",
#         "<link href='http://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.10.4/css/jquery-ui.min.css' rel='stylesheet'>",
#         "<link id='dg-css' href='/nbextensions/qgridjs/qgrid.css' rel='stylesheet'>"
#     ]);
# }
# </script>
# <div class='q-grid-container'>
# <div id='e8e7a36b-784e-4724-b193-12c4dd5866bc' class='q-grid'></div>
# </div>
