# %%
import pandas as pd
import pymongo

# %%
db = pymongo.MongoClient().scraper_meta

# %%
illumina_platforms = [p['accession'] for p in db.platforms.find({'manufacturer': 'Illumina Inc.', 'organism': 'Homo sapiens'}, 
                                       {'_id':0, 'accession': 1})]
print(len(illumina_platforms))
illumina_platforms[:3]
# Out:
# 54
# ['GPL2507', 'GPL2700', 'GPL3896']

# %%
res = list(db.series.find({'platforms': {'$in': illumina_platforms}}, {'_id':0, 'accession': 1, 'supplementary_files': 1}))

# %%
res[:10]
# Out:
# [{'accession': 'GSE21715',
#   'supplementary_files': [{'name': 'GSE21715_non-normalized.txt.gz',
#     'type': 'TXT'}]},
#  {'accession': 'GSE33221',
#   'supplementary_files': [{'name': 'GSE33221_RAW.tar',
#     'type': 'TAR (of BEDGRAPH)'}]},
#  {'accession': 'GSE33220',
#   'supplementary_files': [{'name': 'GSE33220_RAW.tar', 'type': 'TAR'},
#    {'name': 'GSE33220_sample_gene_report_gpl10399.txt.gz', 'type': 'TXT'},
#    {'name': 'GSE33220_sample_probe_report_gpl10558.txt.gz', 'type': 'TXT'},
#    {'name': 'GSE33220_sample_probe_report_gpl6947.txt.gz', 'type': 'TXT'}]},
#  {'accession': 'GSE54267',
#   'supplementary_files': [{'name': 'GSE54267_RAW.tar', 'type': 'TAR'},
#    {'name': 'GSE54267_non_normalized_set4.txt.gz', 'type': 'TXT'}]},
#  {'accession': 'GSE54268',
#   'supplementary_files': [{'name': 'GSE54268_RAW.tar', 'type': 'TAR'},
#    {'name': 'GSE54268_non_normalized_set5.txt.gz', 'type': 'TXT'}]},
#  {'accession': 'GSE54269',
#   'supplementary_files': [{'name': 'GSE54269_RAW.tar', 'type': 'TAR'}]},
#  {'accession': 'GSE54293',
#   'supplementary_files': [{'name': 'GSE54293_Non_normalized_data.txt.gz',
#     'type': 'TXT'},
#    {'name': 'GSE54293_RAW.tar', 'type': 'TAR'}]},
#  {'accession': 'GSE54326',
#   'supplementary_files': [{'name': 'GSE54326_RAW.tar', 'type': 'TAR'},
#    {'name': 'GSE54326_non_normalized.txt.gz', 'type': 'TXT'}]},
#  {'accession': 'GSE54350',
#   'supplementary_files': [{'name': 'GSE54350_RAW.tar', 'type': 'TAR'},
#    {'name': 'GSE54350_non-normalized.txt.gz', 'type': 'TXT'}]},
#  {'accession': 'GSE54400',
#   'supplementary_files': [{'name': 'GSE54400_Non-normalized_data.txt.gz',
#     'type': 'TXT'},
#    {'name': 'GSE54400_RAW.tar', 'type': 'TAR'}]}]

# %%
filenames = [ (s['accession'], f['name'], f['type']) for s in res for f in s['supplementary_files']]

# %%
filenames_df = pd.DataFrame.from_records(filenames, columns=['accession', 'name', 'type'])
filenames_df.head()
# Out:
#   accession                                          name               type
# 0  GSE21715                GSE21715_non-normalized.txt.gz                TXT
# 1  GSE33221                              GSE33221_RAW.tar  TAR (of BEDGRAPH)
# 2  GSE33220                              GSE33220_RAW.tar                TAR
# 3  GSE33220   GSE33220_sample_gene_report_gpl10399.txt.gz                TXT
# 4  GSE33220  GSE33220_sample_probe_report_gpl10558.txt.gz                TXT

# %%
def scrap_type(name):
    t, *other = name.split('_')
    return '_'.join(other)

# %%
filenames_df['suffix'] = filenames_df.name.map(scrap_type)
filenames_df.head()
# Out:
#   accession                                          name               type  \
# 0  GSE21715                GSE21715_non-normalized.txt.gz                TXT
# 1  GSE33221                              GSE33221_RAW.tar  TAR (of BEDGRAPH)
# 2  GSE33220                              GSE33220_RAW.tar                TAR
# 3  GSE33220   GSE33220_sample_gene_report_gpl10399.txt.gz                TXT
# 4  GSE33220  GSE33220_sample_probe_report_gpl10558.txt.gz                TXT
#
#                                 suffix
# 0                non-normalized.txt.gz
# 1                              RAW.tar
# 2                              RAW.tar
# 3   sample_gene_report_gpl10399.txt.gz
# 4  sample_probe_report_gpl10558.txt.gz

# %%
filenames_df.type.value_counts().to_frame()
# Out:
#                                              0
# TXT                                       2346
# TAR                                       1893
# TAR (of TXT)                               176
# SDF                                         50
# TAR (of IDAT)                               48
# TAR (of CEL)                                21
# SRA Study                                   17
# XLS                                         17
# TAR (of BED)                                16
# CSV                                         16
# TAR (of CEL, TXT)                           14
# TAR (of TIFF, TXT)                           8
# TAR (of BED, TXT)                            7
# TIFF                                         6
# TAR (of CEL, CHP)                            6
# TAR (of GPR)                                 5
# TAR (of PAIR)                                4
# TAR (of PAIR, TXT)                           4
# TAR (of BEDGRAPH)                            4
# RDATA                                        4
# IDAT                                         4
# TAR (of CSV)                                 3
# TAR (of CSV, IDAT, LOCS, TIFF, TXT, XML)     3
# TAR (of GPR, TXT)                            3
# XLSX                                         3
# TAR (of IDAT, TXT)                           3
# TAR (of CSV, IDAT)                           2
# TAR (of BED, SAM, TXT, WIG)                  2
# TAR (of CEL, GPR)                            2
# TAR (of WIG)                                 2
# TAR (of CEL, CHP, CNCHP, GQC, TXT)           2
# TAR (of BED, WIG)                            2
# TAR (of XLS)                                 2
# TAR (of IDAT, JPG, XML)                      2
# TAR (of BEDGRAPH, TXT)                       2
# TAR (of CEL, TXT, XML)                       1
# TAR (of FA, GPR, TSV, TXT)                   1
# TAR (of CEL, PAIR, TXT)                      1
# TAR (of BAM, BED)                            1
# TAR (of IDAT, SDF)                           1
# TAR (of GFF, PAIR)                           1
# TAR (of GFF, PAIR, TXT)                      1
# TAR (of BAM)                                 1
# TAR (of CSV, GPR, IDAT)                      1
# TAR (of BEDGRAPH, BW)                        1
# TAR (of LOCS, TIFF, TXT)                     1
# TAR (of BED, BEDGRAPH, FA)                   1
# TAR (of CEL, TXT, WIG)                       1
# TAR (of TXT, WIG)                            1
# TAR (of BED, BW, TXT)                        1
# TAR (of IDAT, LOCS, TIFF, XML)               1
# TAR (of BEDGRAPH, WIG)                       1
# TAR (of XLSX)                                1
# TAR (of TAR)                                 1
# TAR (of CEL, CHP, TXT)                       1
# TAR (of TIFF)                                1
# TAR (of GPR, TIFF, TXT)                      1

# %%
filenames_df.suffix.value_counts().to_frame()
# Out:
#                                                        0
# RAW.tar                                             2256
# non-normalized.txt.gz                               1063
# non_normalized.txt.gz                                221
# non-normalized_data.txt.gz                           208
# normalized.txt.gz                                     56
# Non-normalized_data.txt.gz                            37
#                                                       29
# raw_data.txt.gz                                       22
# nonorm_nobkgd.txt.gz                                  10
# raw.txt.gz                                             9
# matrix_non-normalized.txt.gz                           8
# final_processed_matrix.txt.gz                          8
# RAW.txt.gz                                             6
# README.txt                                             5
# readme.txt                                             5
# non-normalized_matrix.txt.gz                           4
# non-normalized_HumanHT-12_v3.0.txt.gz                  4
# raw_data.txt                                           4
# matrix_non-normalized_data.txt.gz                      4
# Normalized_data_with_annotation.txt.gz                 4
# raw.txt                                                4
# readme.txt.gz                                          3
# non-normalized_full.txt.gz                             3
# non-normalized_signals_pVals.txt.gz                    3
# Non-normalized.txt.gz                                  3
# raw_datamatrix.txt                                     3
# normalized_data.txt.gz                                 3
# DAP_file_list.txt                                      3
# fold-change.txt.gz                                     3
# supplementaryData.Rdata.gz                             3
# ...                                                  ...
# rawdata_methylation.txt.gz                             1
# LNTB_NonNormalized_values.txt.gz                       1
# significant_data.txt.gz                                1
# 4312191012.sdf.gz                                      1
# T09_090001_ControlData.txt.gz                          1
# non-normalized_including_control_probes_ht12.tx...     1
# IPS_non-normalized.txt.gz                              1
# non-normalized_CVID_TRN.txt.gz                         1
# non-normalized_HumanRef-8.txt.gz                       1
# non-normalized_STX4macrophages.txt.gz                  1
# 5626686001.sdf.gz                                      1
# 7183073153.sdf.gz                                      1
# non-normalized_data_Liver.txt.gz                       1
# SCC25_Cal27_non-normalized.txt.gz                      1
# HumanRawDataset1.txt.gz                                1
# phenodata_matrix.txt.gz                                1
# Ref8_non-normalized.txt.gz                             1
# Reactive_vs_MCL_in_situ.txt.gz                         1
# Pearson_061011_MBCBdone.txt.gz                         1
# EZH2_triplicate_Sample_Probe_Profile.txt.gz            1
# raw_column-to-GSM.txt.gz                               1
# Array1_non-normalized.txt.gz                           1
# non_normalized_hTERT.txt.gz                            1
# fold_change_and_ratio.xls.gz                           1
# class_vs_aggr_in_iMCL.txt.gz                           1
# GEO_Annotations.xls.gz                                 1
# 4463361135.sdf.gz                                      1
# norm_analysisI.txt.gz                                  1
# non-normalized_dermis.txt.gz                           1
# 4531933137.sdf.gz                                      1
#
# [721 rows x 1 columns]

# %%
filenames_df[filenames_df.suffix.str.replace('-', '_').str.lower().isin(['non_normalized.txt.gz', 
                                                                         'non_normalized_data.txt.gz'])]
# Out:
#      accession                                 name type  \
# 0     GSE21715       GSE21715_non-normalized.txt.gz  TXT
# 11    GSE54293  GSE54293_Non_normalized_data.txt.gz  TXT
# 14    GSE54326       GSE54326_non_normalized.txt.gz  TXT
# 16    GSE54350       GSE54350_non-normalized.txt.gz  TXT
# 17    GSE54400  GSE54400_Non-normalized_data.txt.gz  TXT
# 20    GSE54465       GSE54465_non-normalized.txt.gz  TXT
# 22    GSE54480       GSE54480_non-normalized.txt.gz  TXT
# 24    GSE54493       GSE54493_non-normalized.txt.gz  TXT
# 28    GSE54608  GSE54608_Non-normalized_data.txt.gz  TXT
# 31    GSE54617       GSE54617_non_normalized.txt.gz  TXT
# 33    GSE54648       GSE54648_non_normalized.txt.gz  TXT
# 35    GSE54820  GSE54820_non-normalized_data.txt.gz  TXT
# 36    GSE54891  GSE54891_Non-normalized_data.txt.gz  TXT
# 39    GSE54979       GSE54979_non-normalized.txt.gz  TXT
# 41    GSE55050       GSE55050_non_normalized.txt.gz  TXT
# 43    GSE55107       GSE55107_non_normalized.txt.gz  TXT
# 45    GSE55109       GSE55109_non_normalized.txt.gz  TXT
# 47    GSE55205       GSE55205_non-normalized.txt.gz  TXT
# 51    GSE55300  GSE55300_Non-normalized_data.txt.gz  TXT
# 55    GSE55319       GSE55319_non-normalized.txt.gz  TXT
# 57    GSE55374       GSE55374_non-normalized.txt.gz  TXT
# 59    GSE55375       GSE55375_non-normalized.txt.gz  TXT
# 61    GSE55439       GSE55439_non_normalized.txt.gz  TXT
# 66    GSE55483       GSE55483_non-normalized.txt.gz  TXT
# 68    GSE55597       GSE55597_non-normalized.txt.gz  TXT
# 71    GSE55639       GSE55639_non_normalized.txt.gz  TXT
# 73    GSE55649       GSE55649_non-normalized.txt.gz  TXT
# 75    GSE55664       GSE55664_non-normalized.txt.gz  TXT
# 77    GSE55691  GSE55691_non-normalized_data.txt.gz  TXT
# 79    GSE55725       GSE55725_non-normalized.txt.gz  TXT
# ...        ...                                  ...  ...
# 4614  GSE36915       GSE36915_non-normalized.txt.gz  TXT
# 4616  GSE36946       GSE36946_non-normalized.txt.gz  TXT
# 4622  GSE43040       GSE43040_non-normalized.txt.gz  TXT
# 4624  GSE44538       GSE44538_non_normalized.txt.gz  TXT
# 4626  GSE45238       GSE45238_non_normalized.txt.gz  TXT
# 4628  GSE46188       GSE46188_non-normalized.txt.gz  TXT
# 4630  GSE49190       GSE49190_non-normalized.txt.gz  TXT
# 4632  GSE47726       GSE47726_non-normalized.txt.gz  TXT
# 4634  GSE62949       GSE62949_non-normalized.txt.gz  TXT
# 4638  GSE40362       GSE40362_non-normalized.txt.gz  TXT
# 4640  GSE37394       GSE37394_non-normalized.txt.gz  TXT
# 4642  GSE29695       GSE29695_non-normalized.txt.gz  TXT
# 4644  GSE25727       GSE25727_non-normalized.txt.gz  TXT
# 4646  GSE23879       GSE23879_non-normalized.txt.gz  TXT
# 4648  GSE23384       GSE23384_non-normalized.txt.gz  TXT
# 4650  GSE54780       GSE54780_non-normalized.txt.gz  TXT
# 4652  GSE21921  GSE21921_non-normalized_data.txt.gz  TXT
# 4658  GSE19580       GSE19580_non-normalized.txt.gz  TXT
# 4660  GSE44381       GSE44381_non-normalized.txt.gz  TXT
# 4677  GSE26253       GSE26253_non-normalized.txt.gz  TXT
# 4679  GSE32225       GSE32225_non-normalized.txt.gz  TXT
# 4700  GSE32651       GSE32651_non-normalized.txt.gz  TXT
# 4702  GSE32918       GSE32918_non-normalized.txt.gz  TXT
# 4705  GSE38202       GSE38202_non-normalized.txt.gz  TXT
# 4708  GSE39945       GSE39945_non-normalized.txt.gz  TXT
# 4710  GSE45257       GSE45257_non_normalized.txt.gz  TXT
# 4712  GSE45821       GSE45821_non-normalized.txt.gz  TXT
# 4714  GSE46581       GSE46581_non-normalized.txt.gz  TXT
# 4716  GSE51451       GSE51451_non_normalized.txt.gz  TXT
# 4718  GSE53127       GSE53127_non-normalized.txt.gz  TXT
#
#                           suffix
# 0          non-normalized.txt.gz
# 11    Non_normalized_data.txt.gz
# 14         non_normalized.txt.gz
# 16         non-normalized.txt.gz
# 17    Non-normalized_data.txt.gz
# 20         non-normalized.txt.gz
# 22         non-normalized.txt.gz
# 24         non-normalized.txt.gz
# 28    Non-normalized_data.txt.gz
# 31         non_normalized.txt.gz
# 33         non_normalized.txt.gz
# 35    non-normalized_data.txt.gz
# 36    Non-normalized_data.txt.gz
# 39         non-normalized.txt.gz
# 41         non_normalized.txt.gz
# 43         non_normalized.txt.gz
# 45         non_normalized.txt.gz
# 47         non-normalized.txt.gz
# 51    Non-normalized_data.txt.gz
# 55         non-normalized.txt.gz
# 57         non-normalized.txt.gz
# 59         non-normalized.txt.gz
# 61         non_normalized.txt.gz
# 66         non-normalized.txt.gz
# 68         non-normalized.txt.gz
# 71         non_normalized.txt.gz
# 73         non-normalized.txt.gz
# 75         non-normalized.txt.gz
# 77    non-normalized_data.txt.gz
# 79         non-normalized.txt.gz
# ...                          ...
# 4614       non-normalized.txt.gz
# 4616       non-normalized.txt.gz
# 4622       non-normalized.txt.gz
# 4624       non_normalized.txt.gz
# 4626       non_normalized.txt.gz
# 4628       non-normalized.txt.gz
# 4630       non-normalized.txt.gz
# 4632       non-normalized.txt.gz
# 4634       non-normalized.txt.gz
# 4638       non-normalized.txt.gz
# 4640       non-normalized.txt.gz
# 4642       non-normalized.txt.gz
# 4644       non-normalized.txt.gz
# 4646       non-normalized.txt.gz
# 4648       non-normalized.txt.gz
# 4650       non-normalized.txt.gz
# 4652  non-normalized_data.txt.gz
# 4658       non-normalized.txt.gz
# 4660       non-normalized.txt.gz
# 4677       non-normalized.txt.gz
# 4679       non-normalized.txt.gz
# 4700       non-normalized.txt.gz
# 4702       non-normalized.txt.gz
# 4705       non-normalized.txt.gz
# 4708       non-normalized.txt.gz
# 4710       non_normalized.txt.gz
# 4712       non-normalized.txt.gz
# 4714       non-normalized.txt.gz
# 4716       non_normalized.txt.gz
# 4718       non-normalized.txt.gz
#
# [1536 rows x 4 columns]

# %%
url_tpl = 'ftp://ftp.ncbi.nlm.nih.gov/geo/series/{prefix}nnn/{accession}/suppl/{file}'

# %%
'GSE55873'[:-3]
# Out:
# 'GSE55'

# %%
! mkdir -p ../data/preproc/cache/

# %%
from os.path import exists, join
import requests as r 
# import requests_ftp

# requests_ftp.monkeypatch_session()
download_dir = '../data/preproc/cache/'
import urllib 
import urllib.request


    
def download_suppl(accession, file):
    url = url_tpl.format(
        prefix=accession[:-3],
        accession=accession,
        file=file
    )
    
    path = join(download_dir, file)
    if not exists(path):     
        with urllib.request.urlopen(url) as response, open(path, 'wb') as out_file:
            data = response.read()
            out_file.write(data)
#         res = r.get(url, stream=True)
#         if res.status_code == 200:
#             with open(path, 'wb') as f:
#                 r.raw.decode_content = True
#                 shutil.copyfileobj(r.raw, f)    
                
    return path

# %%
suppls = filenames_df[filenames_df.suffix.str.replace('-', '_').str.lower().isin(['non_normalized.txt.gz', 
                                                                         'non_normalized_data.txt.gz'])].copy()

# %%
accession = 'GSE24896'
name = suppls[suppls.accession == accession].name.iloc[0]
print(name)

p = download_suppl(accession, name)
print(p)
pd.read_table(p, quotechar="#")
# Out:
# GSE24896_non-normalized.txt.gz
# ../data/preproc/cache/GSE24896_non-normalized.txt.gz
#        The identifiers in the ID_REF column must match the identifiers in the ID column of the referenced platform (GPLxxxx).\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n The Matrix table should include non-normalized signal count data and detectip p-value  \
# 0      "# Values that should be disregarded may eithe...
# 1                                                    NaN
# 2                                                 ID_REF
# 3                                           ILMN_6450255
# 4                                           ILMN_2570615
# 5                                           ILMN_6370619
# 6                                           ILMN_2600039
# 7                                           ILMN_2650615
# 8                                           ILMN_5340672
# 9                                           ILMN_2000519
# 10                                          ILMN_3870044
# 11                                          ILMN_7050209
# 12                                          ILMN_1580181
# 13                                          ILMN_5220554
# 14                                          ILMN_5390438
# 15                                          ILMN_6420681
# 16                                          ILMN_4760377
# 17                                          ILMN_2370438
# 18                                          ILMN_4050154
# 19                                          ILMN_1740066
# 20                                          ILMN_4830092
# 21                                          ILMN_3610072
# 22                                          ILMN_6480136
# 23                                          ILMN_2480367
# 24                                          ILMN_2750273
# 25                                          ILMN_4560202
# 26                                          ILMN_5360113
# 27                                          ILMN_6180500
# 28                                            ILMN_60689
# 29                                          ILMN_1580504
# ...                                                  ...
# 47197                                       ILMN_1170072
# 47198                                       ILMN_3870603
# 47199                                       ILMN_6280093
# 47200                                        ILMN_770152
# 47201                                       ILMN_2000209
# 47202                                       ILMN_5290717
# 47203                                       ILMN_2970368
# 47204                                        ILMN_780114
# 47205                                       ILMN_4850221
# 47206                                       ILMN_7000743
# 47207                                        ILMN_650156
# 47208                                       ILMN_3120307
# 47209                                       ILMN_3800474
# 47210                                       ILMN_4860296
# 47211                                       ILMN_2710059
# 47212                                       ILMN_3800286
# 47213                                       ILMN_3830487
# 47214                                       ILMN_4480441
# 47215                                       ILMN_4570465
# 47216                                       ILMN_1660722
# 47217                                       ILMN_5080121
# 47218                                       ILMN_5700132
# 47219                                        ILMN_670477
# 47220                                       ILMN_4480070
# 47221                                       ILMN_7400296
# 47222                                       ILMN_7050484
# 47223                                       ILMN_7320594
# 47224                                       ILMN_4760356
# 47225                                       ILMN_1300441
# 47226                                       ILMN_4120753
#
#          Unnamed: 1 Unnamed: 2      Unnamed: 3 Unnamed: 4      Unnamed: 5  \
# 0               NaN        NaN             NaN        NaN             NaN
# 1               NaN        NaN             NaN        NaN             NaN
# 47216      133.9         0.55714      128.6         0.62208       110.7
# 47217      170.1         0.16883      168.9          0.2013         158
# 47218      188.2         0.04675      230.9          0.0013       155.4
# 47219      145.7         0.42597      131.3          0.6039       130.4
# 47220         88         0.82468        100         0.78052        91.8
# 47221      431.5               0      510.8               0       487.5
# 47222      354.7               0      470.7               0       396.7
# 47223      903.5               0     1347.7               0       936.1
# 47224      266.3               0      360.5               0         310
# 47225        524               0      660.3               0       501.8
# 47226      320.7               0      353.9               0       277.9
#
#           Unnamed: 11 Unnamed: 12     Unnamed: 13
# 0                 NaN         NaN             NaN
# 1                 NaN         NaN             NaN
# 2      Detection Pval    siBAP1_3  Detection Pval
# 3             0.04156       163.7         0.25844
# 4             0.08442         192         0.04935
# 5              0.3039       134.7         0.56623
# 6             0.26364         162         0.27143
# 7             0.64156       146.1         0.46883
# 8              0.7026       102.9         0.73506
# 9             0.04935       184.9         0.08312
# 10            0.98442        71.8         0.98442
# 11            0.06494         174         0.16494
# 12            0.32597         150         0.40909
# 13            0.83377          83         0.88701
# 14            0.85714        79.8         0.93117
# 15             0.8026        98.6         0.74675
# 16                  0       593.4               0
# 17                  0       577.7               0
# 18            0.93377        90.4         0.81169
# 19            0.44545       158.6         0.30909
# 20            0.27532       173.7         0.16623
# 21            0.84026        76.5         0.95455
# 22            0.70909       127.3         0.62857
# 23            0.61169       134.3         0.57013
# 24            0.05714       169.9         0.19351
# 25            0.25844       156.3         0.33896
# 26            0.86494        73.5         0.97532
# 27            0.93896          86         0.84805
# 28            0.63507       122.6         0.65195
# 29                  0       307.2               0
# ...               ...         ...             ...
# 47197               0         584               0
# 47198         0.03506       201.2         0.01818
# 47199         0.06494       183.1         0.09351
# 47200               0       320.3               0
# 47201               0       494.9               0
# 47202         0.02338       247.8          0.0013
# 47203               0       455.3               0
# 47204         0.87792        73.5         0.97532
# 47205         0.04805       185.2         0.08182
# 47206               0       527.7               0
# 47207         0.58442       129.4         0.61558
# 47208         0.54156       119.2         0.66753
# 47209               0       364.4               0
# 47210         0.77403        94.7         0.77143
# 47211         0.16623       179.8         0.11169
# 47212         0.86494        88.6         0.82987
# 47213         0.11169       160.5         0.29221
# 47214         0.89091        80.3         0.92208
# 47215         0.08442       176.8         0.14286
# 47216         0.65455       112.9         0.70779
# 47217         0.11299       186.6         0.07403
# 47218         0.14026       227.8          0.0013
# 47219         0.43117       146.7         0.45974
# 47220         0.75455        85.9         0.84805
# 47221               0       511.8               0
# 47222               0         324               0
# 47223               0       833.4               0
# 47224               0       342.8               0
# 47225               0       620.4               0
# 47226               0         295               0
#
# [47227 rows x 14 columns]

# %%
suppls.to_pickle('../data/preproc/intermediate/illumina_platforms_suppls.v1.pickle')

# %%
# !scp ../data/preproc/intermediate/illumina_platforms_suppls.v1.pickle npryanichnikov@ui2.computing.kiae.ru:ls2/preproc/tmp
# Out:
# illumina_platforms_suppls.v1.pickle           100%  126KB 126.1KB/s   00:00

# %%
# ?bytes.decode
