# %%
# !mkdir -p ../data/preproc/intermediate/

# %%
# !rsync -vz npryanichnikov@ui2.computing.kiae.ru:/s/ls2/groups/g0064/preproc/preproc.sqlite3 \
    ../data/preproc/intermediate/
# Out:
# preproc.sqlite3
#
# sent 30,978 bytes  received 7,354 bytes  10,952.00 bytes/sec
# total size is 26,576,896  speedup is 693.33

# %%
import pandas as pd
import numpy as np
import sqlite3

# %%
# con = sqlite3.connect()
from sqlalchemy import create_engine
con = create_engine('sqlite:///../data/preproc/intermediate/preproc.sqlite3')

preproc = pd.read_sql_table('task', con)

# %%
FRMA_PLATFORMS = ['GPL' + str(x) for x in [
    570, 571, 96,
    1261,  # organism Mus musculus
    6244,  # getting strange errors. data in matrix
    # 1355,  # NO FRMA, Rattus norvegicus,
    6246,  # no frma package (?). read.affybatch: The affy package can process data from the Gene ST 1.x series of arrays,
    # but you should consider using either the oligo or xps packages, which are specifically
    # designed for these arrays.
    # there is no package called ‘mogene10stv1frmavecs’

    90, # organism Saccharomyces cerevisiae
    3921,
    # 5175, # no frma package (?). read.affybatch: The affy package is not designed for this array type. 
    # Please use either the oligo or xps package.
    # 5188, # no cdf frma packages
    8321,  # organism Mus musculus
]]

AGLIENT_PLATFORMS = ['GPL4133', 'GPL6480', 'GPL15849', 'GPL1708', 'GPL887', 'GPL4091', 'GPL9128', 'GPL7264', 'GPL11387',
             'GPL8687', 'GPL6848', 'GPL2879', 'GPL5477', 'GPL8841', 'GPL10123', 'GPL4093', 'GPL11386', 'GPL10806',
             'GPL8269', 'GPL10150', 'GPL8583', 'GPL15931', 'GPL4126', 'GPL10152', 'GPL16050', 'GPL2567', 'GPL9053',
             'GPL14550', 'GPL5325', 'GPL10808', 'GPL13691', 'GPL9075', 'GPL8736', 'GPL885', 'GPL9777', 'GPL7504',
             'GPL8693', 'GPL2873', 'GPL17077', 'GPL10734', 'GPL13953', 'GPL13607', 'GPL13685', 'GPL7015', 'GPL15560',
             'GPL18623', 'GPL10481', 'GPL16280', 'GPL8737', 'GPL11068']

ILLUMINA_PLATFORMS = list(map('GPL{}'.format, [
   10558, 6947
]))

# %%
preproc['platform'] = preproc.query("type == 'preproc'").name.str.split('_').str.get(1)

# %%
def manufacturer(platform):
    if pd.isnull(platform):
        return 'unknown'
    if platform in AGLIENT_PLATFORMS:
        return 'agilent'
    if platform in FRMA_PLATFORMS:
        return 'affy-frma'
    if platform in ILLUMINA_PLATFORMS:
        return 'illumina'
    return 'unknown'

preproc['manufacturer'] = preproc.platform.map(manufacturer)

# %%
preproc[preproc.name.map(lambda n: n.startswith('GSE40550'))].iloc[0].meta
# Out:
# '{"samples": ["GSM996242", "GSM996243", "GSM996244", "GSM996245"], "platform": "GPL6848", "accession": "GSE40550"}'

# %%
import sys
sys.path.append('..')

# %%
from lib.annotation_api import Api
import lib.annotation_api

# %%
from importlib import reload
reload(lib.annotation_api)
# Out:
# <module 'lib.annotation_api' from '../lib/annotation_api/__init__.py'>

# %%
api = Api('scraper_test_dev')

# %%
import json
from lib.utils import flatten

converted_samples_frma = list(flatten(
    preproc
    .query("type == 'convert-merge' and status == 'done'")
    .meta
    .map(lambda m: json.loads(m).get('samples', []))
    .tolist()
))

# %%
def export_preprocessed(api, samples, annotated=0):
    to_export = [ (accession, dict(preprocessed=1, annotated=annotated))
        for accession in samples
    ]
    api.write_annotation(to_export)

# %%
len(converted_samples_frma)
# Out:
# 190322

# %%
export_preprocessed(api, converted_samples_frma, annotated=1)

# %%
converted_samples_illumina = list((
    preproc
    .query("type == 'preproc' and status == 'done' and manufacturer == 'illumina'")
    .meta
    .map(lambda m: json.loads(m))
    .tolist()
))

# %%
len(converted_samples_illumina)
# Out:
# 606

# %%
(
    preproc
    .query("type == 'preproc' and manufacturer == 'illumina'")
    [['platform', 'meta', 'error', 'status', 'name']]
    .head()
)
# Out:
#       platform                                               meta error  \
# 68    GPL10558  {"samples": ["GSM1587800", "GSM1587801", "GSM1...  None
# 235   GPL10558  {"samples": ["GSM1421924", "GSM1421925", "GSM1...  None
# 1306   GPL6947  {"samples": ["GSM655355", "GSM655354", "GSM655...  None
# 1494   GPL6947  {"samples": ["GSM796536", "GSM796537", "GSM796...  None
# 2015   GPL6947  {"samples": ["GSM589498", "GSM589499", "GSM589...  None
#
#      status               name
# 68     skip  GSE65136_GPL10558
# 235    skip  GSE58893_GPL10558
# 1306   skip   GSE26627_GPL6947
# 1494   skip   GSE32140_GPL6947
# 2015   skip   GSE23921_GPL6947

# %%
converted_samples_illumina[:2]
# Out:
# [{'accession': 'GSE22427',
#   'platform': 'GPL10558',
#   'samples_count': 12,
#   'suppl_file': 'GSE22427_non-normalized.txt.gz'},
#  {'accession': 'GSE27124',
#   'platform': 'GPL10558',
#   'samples_count': 12,
#   'suppl_file': 'GSE27124_non-normalized.txt.gz'}]

# %%
import pymongo

# %%
db = pymongo.MongoClient().scraper_test_dev

# %%
def get_samples(item):
    samples = list(db.samples.find({
            'series': item['accession'],
            'platform': item['platform']
        },{'_id': 0, 'accession': 1}))
    return [s['accession'] for s in samples]

# %%
get_samples({'accession': 'GSE22427',
  'platform': 'GPL10558',
  'samples_count': 12,
  'suppl_file': 'GSE22427_non-normalized.txt.gz'})
# Out:
# ['GSM557442',
#  'GSM557441',
#  'GSM557440',
#  'GSM557439',
#  'GSM557438',
#  'GSM557437',
#  'GSM557436',
#  'GSM557435',
#  'GSM557434',
#  'GSM557433',
#  'GSM557432',
#  'GSM557431']

# %%
converted_series_illumina = converted_samples_illumina

# %%
converted_samples_illumina = list(flatten(map(get_samples, converted_series_illumina)))

# %%
len(converted_samples_illumina)
# Out:
# 20367

# %%
(
 preproc
    .query("type == 'preproc' and status == 'done' and manufacturer == 'illumina'")
    .meta
    .map(lambda m: int(json.loads(m)['samples_count']))
    .sum()
)
# Out:
# 20367

# %%
converted_samples_illumina[:2]
# Out:
# ['GSM557442', 'GSM557441']

# %%
export_preprocessed(api, converted_samples_illumina, annotated=1)

# %%
preproc[preproc.name.like()]
# Out:
#           id               name status  \
# 0          1    GSE53224_GPL570   done
# 1          2    GSE53183_GPL570   done
# 2          3    GSE53157_GPL570   done
# 3          4   GSE65721_GPL5082   skip
# 4          5    GSE65721_GPL570   done
# 5          6    GSE53092_GPL570   done
# 6          7    GSE65707_GPL570   done
# 7          8    GSE53059_GPL570   done
# 8          9    GSE53046_GPL570   done
# 9         10    GSE53012_GPL570   done
# 10        11  GSE52980_GPL11154   skip
# 11        12  GSE52980_GPL13534   skip
# 12        13    GSE52980_GPL570   done
# 13        14    GSE49243_GPL570   done
# 14        15  GSE65647_GPL14550  error
# 15        16    GSE65647_GPL570   done
# 16        17    GSE49232_GPL570   done
# 17        18    GSE52896_GPL570   done
# 18        19    GSE52892_GPL570   done
# 19        20    GSE52889_GPL570   done
# 20        21  GSE52847_GPL17954   skip
# 21        22    GSE52847_GPL570   done
# 22        23    GSE52735_GPL570   done
# 23        24  GSE52717_GPL16288   skip
# 24        25  GSE52717_GPL17989   skip
# 25        26    GSE52717_GPL570   done
# 26        27    GSE52712_GPL570   done
# 27        28    GSE52707_GPL570   done
# 28        29  GSE52658_GPL11154   skip
# 29        30    GSE52658_GPL570   done
# ...      ...                ...    ...
# 43426  43462  GSE61992_GPL10558  error
# 43427  43463  GSE62359_GPL10558  error
# 43428  43464   GSE62373_GPL6947   done
# 43429  43465  GSE62384_GPL10558  error
# 43430  43466  GSE62441_GPL10558  error
# 43431  43467  GSE62460_GPL10558   done
# 43432  43468  GSE62464_GPL10558  error
# 43433  43469  GSE62627_GPL10558   done
# 43434  43470  GSE63072_GPL10558   done
# 43435  43471  GSE63098_GPL10558  error
# 43436  43472  GSE63146_GPL10558   done
# 43437  43473  GSE63160_GPL10558  error
# 43438  43474  GSE63988_GPL10558  error
# 43439  43475  GSE64007_GPL10558   done
# 43440  43476  GSE64263_GPL10558  error
# 43441  43477  GSE65128_GPL10558   done
# 43442  43478  GSE65133_GPL10558   done
# 43443  43479  GSE65412_GPL10558   done
# 43444  43480   GSE65479_GPL6947   done
# 43445  43481   GSE65483_GPL6947   done
# 43446  43482  GSE65517_GPL10558   done
# 43447  43483  GSE65879_GPL10558  error
# 43448  43484  GSE66355_GPL10558  error
# 43449  43485  GSE66373_GPL10558   done
# 43450  43486  GSE66495_GPL10558  error
# 43451  43487  GSE67093_GPL10558  error
# 43452  43488  GSE67629_GPL10558  error
# 43453  43489  GSE69288_GPL10558   done
# 43454  43490  GSE69381_GPL10558  error
# 43455  43491  GSE69528_GPL10558  error
#
#                                                     meta     type  \
# 0      {"samples": ["GSM1287918", "GSM1287919", "GSM1...  preproc
# 1      {"samples": ["GSM1286097", "GSM1286098", "GSM1...  preproc
# 2      {"samples": ["GSM1283115", "GSM1283116", "GSM1...  preproc
# 3      {"samples": ["GSM1603234", "GSM1603235", "GSM1...  preproc
# 4      {"samples": ["GSM1603354", "GSM1603355", "GSM1...  preproc
# 5      {"samples": ["GSM1282316", "GSM1282317", "GSM1...  preproc
# 6      {"samples": ["GSM1603354", "GSM1603355", "GSM1...  preproc
# 7      {"samples": ["GSM1281432", "GSM1281433", "GSM1...  preproc
# 8      {"samples": ["GSM1281025", "GSM1281026", "GSM1...  preproc
# 9      {"samples": ["GSM1280329", "GSM1280330", "GSM1...  preproc
# 10     {"samples": ["GSM1279669", "GSM1279668", "GSM1...  preproc
# 11     {"samples": ["GSM1255769", "GSM1255770", "GSM1...  preproc
# 12     {"samples": ["GSM1638783", "GSM1638784", "GSM1...  preproc
# 13     {"samples": ["GSM1195778", "GSM1195779", "GSM1...  preproc
# 14     {"samples": ["GSM1602365", "GSM1602366", "GSM1...  preproc
# 15     {"samples": ["GSM1602409", "GSM1602410", "GSM1...  preproc
# 16     {"samples": ["GSM1195690", "GSM1195692", "GSM1...  preproc
# 17     {"samples": ["GSM1277638", "GSM1277639", "GSM1...  preproc
# 18     {"samples": ["GSM1277571", "GSM1277572", "GSM1...  preproc
# 19     {"samples": ["GSM1277537", "GSM1277538", "GSM1...  preproc
# 20     {"samples": ["GSM1268055", "GSM1268056", "GSM1...  preproc
# 21     {"samples": ["GSM1275067", "GSM1275068", "GSM1...  preproc
# 22     {"samples": ["GSM1275067", "GSM1275068", "GSM1...  preproc
# 23     {"samples": ["GSM1274528", "GSM1274529", "GSM1...  preproc
# 24     {"samples": ["GSM1274506", "GSM1274507", "GSM1...  preproc
# 25     {"samples": ["GSM1274482", "GSM1274483", "GSM1...  preproc
# 26     {"samples": ["GSM1274482", "GSM1274483", "GSM1...  preproc
# 27     {"samples": ["GSM1274400", "GSM1274402", "GSM1...  preproc
# 28     {"samples": ["GSM1273642", "GSM1273643", "GSM1...  preproc
# 29     {"samples": ["GSM1260408", "GSM1260409", "GSM1...  preproc
# ...                                                  ...      ...
# 43426  {"samples_count": 26, "suppl_file": "GSE61992_...  preproc
# 43427  {"samples_count": 6, "suppl_file": "GSE62359_N...  preproc
# 43428  {"samples_count": 45, "suppl_file": "GSE62373_...  preproc
# 43429  {"samples_count": 24, "suppl_file": "GSE62384_...  preproc
# 43430  {"samples_count": 12, "suppl_file": "GSE62441_...  preproc
# 43431  {"samples_count": 12, "suppl_file": "GSE62460_...  preproc
# 43432  {"samples_count": 8, "suppl_file": "GSE62464_n...  preproc
# 43433  {"samples_count": 174, "suppl_file": "GSE62627...  preproc
# 43434  {"samples_count": 18, "suppl_file": "GSE63072_...  preproc
# 43435  {"samples_count": 121, "suppl_file": "GSE63098...  preproc
# 43436  {"samples_count": 12, "suppl_file": "GSE63146_...  preproc
# 43437  {"samples_count": 4, "suppl_file": "GSE63160_n...  preproc
# 43438  {"samples_count": 11, "suppl_file": "GSE63988_...  preproc
# 43439  {"samples_count": 12, "suppl_file": "GSE64007_...  preproc
# 43440  {"samples_count": 34, "suppl_file": "GSE64263_...  preproc
# 43441  {"samples_count": 36, "suppl_file": "GSE65128_...  preproc
# 43442  {"samples_count": 20, "suppl_file": "GSE65133_...  preproc
# 43443  {"samples_count": 20, "suppl_file": "GSE65412_...  preproc
# 43444  {"samples_count": 12, "suppl_file": "GSE65479_...  preproc
# 43445  {"samples_count": 12, "suppl_file": "GSE65483_...  preproc
# 43446  {"samples_count": 13, "suppl_file": "GSE65517_...  preproc
# 43447  {"samples_count": 12, "suppl_file": "GSE65879_...  preproc
# 43448  {"samples_count": 17, "suppl_file": "GSE66355_...  preproc
# 43449  {"samples_count": 12, "suppl_file": "GSE66373_...  preproc
# 43450  {"samples_count": 19, "suppl_file": "GSE66495_...  preproc
# 43451  {"samples_count": 22, "suppl_file": "GSE67093_...  preproc
# 43452  {"samples_count": 3, "suppl_file": "GSE67629_n...  preproc
# 43453  {"samples_count": 2, "suppl_file": "GSE69288_n...  preproc
# 43454  {"samples_count": 10, "suppl_file": "GSE69381_...  preproc
# 43455  {"samples_count": 138, "suppl_file": "GSE69528...  preproc
#
#              error              creation_date            submission_date  \
# 0             None 2015-08-21 18:46:27.696759                        NaT
# 1             None 2015-08-21 18:46:27.698587                        NaT
# 2             None 2015-08-21 18:46:27.699732                        NaT
# 3             None 2015-08-21 18:46:27.700555                        NaT
# 4             None 2015-08-21 18:46:27.701362                        NaT
# 5             None 2015-08-21 18:46:27.702123                        NaT
# 6             None 2015-08-21 18:46:27.702899                        NaT
# 7             None 2015-08-21 18:46:27.703622                        NaT
# 8             None 2015-08-21 18:46:27.704425                        NaT
# 9             None 2015-08-21 18:46:27.705136                        NaT
# 10            None 2015-08-21 18:46:27.705871                        NaT
# 11            None 2015-08-21 18:46:27.706594                        NaT
# 12            None 2015-08-21 18:46:27.707393                        NaT
# 13            None 2015-08-21 18:46:27.708200                        NaT
# 14     interrupted 2015-08-21 18:46:27.708984                        NaT
# 15            None 2015-08-21 18:46:27.709752                        NaT
# 16            None 2015-08-21 18:46:27.710581                        NaT
# 17            None 2015-08-21 18:46:27.711355                        NaT
# 18            None 2015-08-21 18:46:27.712100                        NaT
# 19            None 2015-08-21 18:46:27.712847                        NaT
# 20            None 2015-08-21 18:46:27.713584                        NaT
# 21            None 2015-08-21 18:46:27.714359                        NaT
# 22            None 2015-08-21 18:46:27.715151                        NaT
# 23            None 2015-08-21 18:46:27.715913                        NaT
# 24            None 2015-08-21 18:46:27.716626                        NaT
# 25            None 2015-08-21 18:46:27.717359                        NaT
# 26            None 2015-08-21 18:46:27.718096                        NaT
# 27            None 2015-08-21 18:46:27.718910                        NaT
# 28            None 2015-08-21 18:46:27.719674                        NaT
# 29            None 2015-08-21 18:46:27.720335                        NaT
# ...            ...                        ...                        ...
# 43426   exec-error 2015-10-19 13:20:57.377384 2015-10-19 13:31:52.404642
# 43427   exec-error 2015-10-19 13:20:57.377428 2015-10-19 13:31:52.921765
# 43428         None 2015-10-19 13:20:57.377472 2015-10-19 13:31:53.607782
# 43429   exec-error 2015-10-19 13:20:57.377516 2015-10-19 13:31:54.903798
# 43430   exec-error 2015-10-19 13:20:57.377560 2015-10-19 13:31:55.629807
# 43431         None 2015-10-19 13:20:57.377604 2015-10-19 13:31:57.178831
# 43432   exec-error 2015-10-19 13:20:57.377649 2015-10-19 13:31:58.293825
# 43433         None 2015-10-19 13:20:57.377693 2015-10-19 13:31:59.791736
# 43434         None 2015-10-19 13:20:57.377737 2015-10-19 13:32:01.009863
# 43435   exec-error 2015-10-19 13:20:57.377781 2015-10-19 13:32:02.354859
# 43436         None 2015-10-19 13:20:57.377825 2015-10-19 13:32:03.815913
# 43437   exec-error 2015-10-19 13:20:57.377869 2015-10-19 13:32:04.365923
# 43438   exec-error 2015-10-19 13:20:57.377913 2015-10-19 13:32:04.882872
# 43439         None 2015-10-19 13:20:57.377956 2015-10-19 13:32:09.925892
# 43440   exec-error 2015-10-19 13:20:57.378000 2015-10-19 13:32:10.552004
# 43441         None 2015-10-19 13:20:57.378043 2015-10-19 13:32:11.049896
# 43442         None 2015-10-19 13:20:57.378088 2015-10-19 13:32:12.039023
# 43443         None 2015-10-19 13:20:57.378131 2015-10-19 13:32:12.643884
# 43444         None 2015-10-19 13:20:57.378175 2015-10-19 13:32:12.967028
# 43445         None 2015-10-19 13:20:57.378225 2015-10-19 13:32:14.778075
# 43446         None 2015-10-19 13:20:57.378269 2015-10-19 13:32:16.309151
# 43447   exec-error 2015-10-19 13:20:57.378320 2015-10-19 13:32:17.266100
# 43448   exec-error 2015-10-19 13:20:57.378364 2015-10-19 13:32:18.155085
# 43449         None 2015-10-19 13:20:57.378407 2015-10-19 13:32:18.594323
# 43450   exec-error 2015-10-19 13:20:57.378451 2015-10-19 13:32:19.341009
# 43451   exec-error 2015-10-19 13:20:57.378496 2015-10-19 13:32:21.187041
# 43452   exec-error 2015-10-19 13:20:57.378539 2015-10-19 13:32:21.816044
# 43453         None 2015-10-19 13:20:57.378583 2015-10-19 13:32:22.288051
# 43454   exec-error 2015-10-19 13:20:57.378627 2015-10-19 13:32:23.309069
# 43455   exec-error 2015-10-19 13:20:57.378671 2015-10-19 13:32:25.996484
#
#       run_date done_date  platform manufacturer
# 0          NaT       NaT    GPL570    affy-frma
# 1          NaT       NaT    GPL570    affy-frma
# 2          NaT       NaT    GPL570    affy-frma
# 3          NaT       NaT   GPL5082      unknown
# 4          NaT       NaT    GPL570    affy-frma
# 5          NaT       NaT    GPL570    affy-frma
# 6          NaT       NaT    GPL570    affy-frma
# 7          NaT       NaT    GPL570    affy-frma
# 8          NaT       NaT    GPL570    affy-frma
# 9          NaT       NaT    GPL570    affy-frma
# 10         NaT       NaT  GPL11154      unknown
# 11         NaT       NaT  GPL13534      unknown
# 12         NaT       NaT    GPL570    affy-frma
# 13         NaT       NaT    GPL570    affy-frma
# 14         NaT       NaT  GPL14550      agilent
# 15         NaT       NaT    GPL570    affy-frma
# 16         NaT       NaT    GPL570    affy-frma
# 17         NaT       NaT    GPL570    affy-frma
# 18         NaT       NaT    GPL570    affy-frma
# 19         NaT       NaT    GPL570    affy-frma
# 20         NaT       NaT  GPL17954      unknown
# 21         NaT       NaT    GPL570    affy-frma
# 22         NaT       NaT    GPL570    affy-frma
# 23         NaT       NaT  GPL16288      unknown
# 24         NaT       NaT  GPL17989      unknown
# 25         NaT       NaT    GPL570    affy-frma
# 26         NaT       NaT    GPL570    affy-frma
# 27         NaT       NaT    GPL570    affy-frma
# 28         NaT       NaT  GPL11154      unknown
# 29         NaT       NaT    GPL570    affy-frma
# ...        ...       ...       ...          ...
# 43426      NaT       NaT  GPL10558     illumina
# 43427      NaT       NaT  GPL10558     illumina
# 43428      NaT       NaT   GPL6947     illumina
# 43429      NaT       NaT  GPL10558     illumina
# 43430      NaT       NaT  GPL10558     illumina
# 43431      NaT       NaT  GPL10558     illumina
# 43432      NaT       NaT  GPL10558     illumina
# 43433      NaT       NaT  GPL10558     illumina
# 43434      NaT       NaT  GPL10558     illumina
# 43435      NaT       NaT  GPL10558     illumina
# 43436      NaT       NaT  GPL10558     illumina
# 43437      NaT       NaT  GPL10558     illumina
# 43438      NaT       NaT  GPL10558     illumina
# 43439      NaT       NaT  GPL10558     illumina
# 43440      NaT       NaT  GPL10558     illumina
# 43441      NaT       NaT  GPL10558     illumina
# 43442      NaT       NaT  GPL10558     illumina
# 43443      NaT       NaT  GPL10558     illumina
# 43444      NaT       NaT   GPL6947     illumina
# 43445      NaT       NaT   GPL6947     illumina
# 43446      NaT       NaT  GPL10558     illumina
# 43447      NaT       NaT  GPL10558     illumina
# 43448      NaT       NaT  GPL10558     illumina
# 43449      NaT       NaT  GPL10558     illumina
# 43450      NaT       NaT  GPL10558     illumina
# 43451      NaT       NaT  GPL10558     illumina
# 43452      NaT       NaT  GPL10558     illumina
# 43453      NaT       NaT  GPL10558     illumina
# 43454      NaT       NaT  GPL10558     illumina
# 43455      NaT       NaT  GPL10558     illumina
#
# [43456 rows x 12 columns]

# %%
(
    preproc
    [preproc.platform.isin(['GPL6848', 'GPL6480', 'A-AGIL-28', 'GPL17077', 'GPL20163',
       'A-MEXP-2276', 'GPL16770', 'A-MEXP-2140'])]
    .groubpy('platform')
    .status.value_counts()
)
# Out:
#                   0
# platform
# GPL17077 error   67
#          done    12
# GPL6480  error  403
#          done   148
# GPL6848  error   28
#          done    22

# %%
(
    preproc
    [preproc.platform.isin(['GPL6848', 'GPL6480', 'A-AGIL-28', 'GPL17077', 'GPL20163',
       'A-MEXP-2276', 'GPL16770', 'A-MEXP-2140'])]
    .status.value_counts()
)
# Out:
# error    498
# done     182
# dtype: int64

# %%
converted_samples_agilent = list((
    preproc
    .query("type == 'preproc' and status == 'done' and manufacturer == 'agilent'")
    .meta
    .map(lambda m: json.loads(m))
    .tolist()
))

# %%
converted_samples_agilent[:1]
# Out:
# [{'accession': 'GSE26863',
#   'platform': 'GPL9128',
#   'samples': ['GSM660764',
#    'GSM660764',
#    'GSM660765',
#    'GSM660765',
#    'GSM660766',
#    'GSM660766',
#    'GSM660767',
#    'GSM660767',
#    'GSM660768',
#    'GSM660768',
#    'GSM660769',
#    'GSM660769',
#    'GSM660770',
#    'GSM660770',
#    'GSM660771',
#    'GSM660772',
#    'GSM660772',
#    'GSM660773',
#    'GSM660773',
#    'GSM660774',
#    'GSM660774',
#    'GSM660775',
#    'GSM660775',
#    'GSM660776',
#    'GSM660776',
#    'GSM660777',
#    'GSM660778',
#    'GSM660777',
#    'GSM660778',
#    'GSM660779',
#    'GSM660779',
#    'GSM660780',
#    'GSM660780',
#    'GSM660781',
#    'GSM660781',
#    'GSM660782',
#    'GSM660782',
#    'GSM660783',
#    'GSM660783',
#    'GSM660784',
#    'GSM660771',
#    'GSM660784',
#    'GSM660785',
#    'GSM660785',
#    'GSM660786',
#    'GSM660786',
#    'GSM660787',
#    'GSM660787',
#    'GSM660788',
#    'GSM660788',
#    'GSM660789',
#    'GSM660789',
#    'GSM660790',
#    'GSM660790',
#    'GSM660791',
#    'GSM660791',
#    'GSM660792',
#    'GSM660792',
#    'GSM660793',
#    'GSM660793',
#    'GSM660794',
#    'GSM660794',
#    'GSM660795',
#    'GSM660795',
#    'GSM660796',
#    'GSM660796',
#    'GSM660797',
#    'GSM660797',
#    'GSM660798',
#    'GSM660798',
#    'GSM660799',
#    'GSM660799',
#    'GSM660800',
#    'GSM660800',
#    'GSM660801',
#    'GSM660801',
#    'GSM660802',
#    'GSM660802',
#    'GSM660803',
#    'GSM660803',
#    'GSM660804',
#    'GSM660804',
#    'GSM660805',
#    'GSM660806',
#    'GSM660805',
#    'GSM660806',
#    'GSM660807',
#    'GSM660807',
#    'GSM660808',
#    'GSM660808',
#    'GSM660809',
#    'GSM660809',
#    'GSM660810',
#    'GSM660810',
#    'GSM660811',
#    'GSM660811',
#    'GSM660812',
#    'GSM660812',
#    'GSM660813',
#    'GSM660814',
#    'GSM660814',
#    'GSM660813',
#    'GSM660815',
#    'GSM660815',
#    'GSM660816',
#    'GSM660816',
#    'GSM660817',
#    'GSM660817',
#    'GSM660818',
#    'GSM660818',
#    'GSM660819',
#    'GSM660819',
#    'GSM660820',
#    'GSM660820',
#    'GSM660821',
#    'GSM660821',
#    'GSM660822',
#    'GSM660822',
#    'GSM660823',
#    'GSM660823',
#    'GSM660824',
#    'GSM660824',
#    'GSM660825',
#    'GSM660825',
#    'GSM660826',
#    'GSM660826',
#    'GSM660827',
#    'GSM660827',
#    'GSM660828',
#    'GSM660828',
#    'GSM660829',
#    'GSM660829',
#    'GSM660830',
#    'GSM660830',
#    'GSM660831',
#    'GSM660831',
#    'GSM660832',
#    'GSM660832',
#    'GSM660833',
#    'GSM660833',
#    'GSM660834',
#    'GSM660834',
#    'GSM660835',
#    'GSM660835',
#    'GSM660836',
#    'GSM660836',
#    'GSM660837',
#    'GSM660837',
#    'GSM660838',
#    'GSM660838',
#    'GSM660839',
#    'GSM660839',
#    'GSM660840',
#    'GSM660840',
#    'GSM660841',
#    'GSM660841',
#    'GSM660842',
#    'GSM660842',
#    'GSM660843',
#    'GSM660843',
#    'GSM660844',
#    'GSM660844',
#    'GSM660845',
#    'GSM660845',
#    'GSM660846',
#    'GSM660846',
#    'GSM660847',
#    'GSM660847',
#    'GSM660848',
#    'GSM660848',
#    'GSM660849',
#    'GSM660849',
#    'GSM660850',
#    'GSM660850',
#    'GSM660851',
#    'GSM660851',
#    'GSM660852',
#    'GSM660852',
#    'GSM660853',
#    'GSM660853',
#    'GSM660854',
#    'GSM660854',
#    'GSM660855',
#    'GSM660856',
#    'GSM660855',
#    'GSM660857',
#    'GSM660856',
#    'GSM660857',
#    'GSM660858',
#    'GSM660858',
#    'GSM660859',
#    'GSM660859',
#    'GSM660860',
#    'GSM660860',
#    'GSM660861',
#    'GSM660862',
#    'GSM660861',
#    'GSM660862',
#    'GSM660863',
#    'GSM660863',
#    'GSM660864',
#    'GSM660864',
#    'GSM660865',
#    'GSM660865',
#    'GSM660866',
#    'GSM660866',
#    'GSM660867',
#    'GSM660867',
#    'GSM660868',
#    'GSM660868',
#    'GSM660869',
#    'GSM660869',
#    'GSM660870',
#    'GSM660870',
#    'GSM660871',
#    'GSM660871',
#    'GSM660872',
#    'GSM660872',
#    'GSM660873',
#    'GSM660873',
#    'GSM660874',
#    'GSM660874',
#    'GSM660875',
#    'GSM660875',
#    'GSM660876',
#    'GSM660876',
#    'GSM660877',
#    'GSM660877',
#    'GSM660878',
#    'GSM660878',
#    'GSM660879',
#    'GSM660879',
#    'GSM660880',
#    'GSM660880',
#    'GSM660881',
#    'GSM660881',
#    'GSM660882',
#    'GSM660882',
#    'GSM660883',
#    'GSM660883',
#    'GSM660884',
#    'GSM660884',
#    'GSM660885',
#    'GSM660885',
#    'GSM660886',
#    'GSM660886',
#    'GSM660887',
#    'GSM660887',
#    'GSM660888',
#    'GSM660888',
#    'GSM660889',
#    'GSM660889',
#    'GSM660890',
#    'GSM660890',
#    'GSM660891',
#    'GSM660891',
#    'GSM660892',
#    'GSM660892',
#    'GSM660893',
#    'GSM660893',
#    'GSM660894',
#    'GSM660894',
#    'GSM660895',
#    'GSM660895',
#    'GSM660896',
#    'GSM660896',
#    'GSM660897',
#    'GSM660897',
#    'GSM660898',
#    'GSM660898',
#    'GSM660899',
#    'GSM660899',
#    'GSM660900',
#    'GSM660900',
#    'GSM660901',
#    'GSM660901',
#    'GSM660902',
#    'GSM660902',
#    'GSM660903',
#    'GSM660903',
#    'GSM660904',
#    'GSM660904',
#    'GSM660905',
#    'GSM660905',
#    'GSM660906',
#    'GSM660906',
#    'GSM660907',
#    'GSM660907',
#    'GSM660908',
#    'GSM660909',
#    'GSM660909',
#    'GSM660910',
#    'GSM660910',
#    'GSM660911',
#    'GSM660912',
#    'GSM660913',
#    'GSM660913',
#    'GSM660908',
#    'GSM660914',
#    'GSM660914',
#    'GSM660915',
#    'GSM660915',
#    'GSM660912',
#    'GSM660916',
#    'GSM660911',
#    'GSM660916',
#    'GSM660917',
#    'GSM660917',
#    'GSM660918',
#    'GSM660918',
#    'GSM660919',
#    'GSM660919',
#    'GSM660920',
#    'GSM660920',
#    'GSM660921',
#    'GSM660921',
#    'GSM660922',
#    'GSM660922',
#    'GSM660923',
#    'GSM660923',
#    'GSM660924',
#    'GSM660924',
#    'GSM660925',
#    'GSM660925',
#    'GSM660926',
#    'GSM660926',
#    'GSM660927',
#    'GSM660927',
#    'GSM660928',
#    'GSM660928',
#    'GSM660929',
#    'GSM660929',
#    'GSM660930',
#    'GSM660930',
#    'GSM660931',
#    'GSM660931',
#    'GSM660932',
#    'GSM660932',
#    'GSM660933',
#    'GSM660933',
#    'GSM660934',
#    'GSM660935',
#    'GSM660934',
#    'GSM660936',
#    'GSM660936',
#    'GSM660935',
#    'GSM660937',
#    'GSM660937',
#    'GSM660938',
#    'GSM660939',
#    'GSM660939',
#    'GSM660938',
#    'GSM660940',
#    'GSM660940',
#    'GSM660941',
#    'GSM660941',
#    'GSM660942',
#    'GSM660942',
#    'GSM660943',
#    'GSM660943',
#    'GSM660944',
#    'GSM660944',
#    'GSM660945',
#    'GSM660945',
#    'GSM660946',
#    'GSM660946',
#    'GSM660948',
#    'GSM660948',
#    'GSM660949',
#    'GSM660949',
#    'GSM660950',
#    'GSM660947',
#    'GSM660947',
#    'GSM660950',
#    'GSM660951',
#    'GSM660951',
#    'GSM660952',
#    'GSM660952',
#    'GSM660953',
#    'GSM660954',
#    'GSM660953',
#    'GSM660954',
#    'GSM660955',
#    'GSM660955',
#    'GSM660956',
#    'GSM660957',
#    'GSM660956',
#    'GSM660957',
#    'GSM660958',
#    'GSM660958',
#    'GSM660960',
#    'GSM660960',
#    'GSM660961',
#    'GSM660962',
#    'GSM660962',
#    'GSM660963',
#    'GSM660963',
#    'GSM660959',
#    'GSM660964',
#    'GSM660965',
#    'GSM660959',
#    'GSM660965',
#    'GSM660966',
#    'GSM660966',
#    'GSM660961',
#    'GSM660964',
#    'GSM660967',
#    'GSM660967',
#    'GSM660968',
#    'GSM660968',
#    'GSM660969',
#    'GSM660969',
#    'GSM660970',
#    'GSM660970',
#    'GSM660971',
#    'GSM660971',
#    'GSM660972',
#    'GSM660972',
#    'GSM660973',
#    'GSM660973',
#    'GSM660974',
#    'GSM660974',
#    'GSM660975',
#    'GSM660975',
#    'GSM660976',
#    'GSM660976',
#    'GSM660977',
#    'GSM660977',
#    'GSM660978',
#    'GSM660979',
#    'GSM660978',
#    'GSM660979',
#    'GSM660980',
#    'GSM660980',
#    'GSM660981',
#    'GSM660981',
#    'GSM660982',
#    'GSM660982',
#    'GSM660983',
#    'GSM660983',
#    'GSM660984',
#    'GSM660984',
#    'GSM660985',
#    'GSM660985',
#    'GSM660986',
#    'GSM660986',
#    'GSM660987',
#    'GSM660987',
#    'GSM660988',
#    'GSM660988',
#    'GSM660989',
#    'GSM660989',
#    'GSM660990',
#    'GSM660990',
#    'GSM660991',
#    'GSM660991',
#    'GSM660992',
#    'GSM660992',
#    'GSM660993',
#    'GSM660993',
#    'GSM660994',
#    'GSM660994',
#    'GSM660995',
#    'GSM660995',
#    'GSM660996',
#    'GSM660996',
#    'GSM660997',
#    'GSM660997',
#    'GSM660998',
#    'GSM660998',
#    'GSM660999',
#    'GSM660999',
#    'GSM661000',
#    'GSM661000',
#    'GSM661001',
#    'GSM661001',
#    'GSM661002',
#    'GSM661002',
#    'GSM661003',
#    'GSM661004',
#    'GSM661005',
#    'GSM661004',
#    'GSM661005',
#    'GSM661006',
#    'GSM661003',
#    'GSM661006',
#    'GSM661007',
#    'GSM661007',
#    'GSM661008',
#    'GSM661008',
#    'GSM661009',
#    'GSM661009',
#    'GSM661010',
#    'GSM661011',
#    'GSM661010',
#    'GSM661011',
#    'GSM661012',
#    'GSM661012',
#    'GSM661013',
#    'GSM661013',
#    'GSM661014',
#    'GSM661014',
#    'GSM661015',
#    'GSM661015',
#    'GSM661016',
#    'GSM661016',
#    'GSM661017',
#    'GSM661017']}]

# %%
_t = [s for se in converted_samples_agilent for s in se['samples']]
export_preprocessed(api, _t, annotated=0)

# %%
len(_t)
# Out:
# 24209
