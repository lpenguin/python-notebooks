# %%
import sys
sys.path.append('..')

# %%
import requests as r
import pandas as pd

from lib.classification.elastic import search_term, collapse_matches
from lib.obo import read_ontology
from elasticsearch import Elasticsearch
es = Elasticsearch()

# %%
diseases = r.get('http://amp.pharm.mssm.edu/L1000CDS2/diseases').json()

# %%
data = pd.DataFrame(diseases)
data[:10]
# Out:
#                         _id                                  desc  \
# 0  552849170bdc500e55660240                         Adrenal gland
# 1  552849170bdc500e55660241                        Hepatic Tissue
# 2  552849170bdc500e55660242  Muscle - Striated (Skeletal) (MMHCC)
# 3  552849170bdc500e55660243                         Sciatic Nerve
# 4  552849170bdc500e55660244      CNS - Brain - Cerebellum (MMHCC)
# 5  552849170bdc500e55660245                        frontal cortex
# 6  552849170bdc500e55660246                      Endothelial cell
# 7  552849170bdc500e55660247                     Synovial Membrane
# 8  552849170bdc500e55660248     CNS - Brain - Hippocampus (MMHCC)
# 9  552849170bdc500e55660249  Muscle - Striated (Skeletal) (MMHCC)
#
#                                                 term
# 0                           Cushing syndrome_gse4060
# 1                          Hepatic lipidosis_gse5538
# 2  Melas - mitochondrial myopathy, encephalopathy...
# 3                Peripheral motor neuropathy_gse1947
# 4                              Down syndrome_gse1611
# 5                           Bipolar disorder_gse5388
# 6                         Sickle cell anemia_gse9877
# 7                  Ra (rheumatoid arthritis)_gse1919
# 8                            Anxiety disorder_gse932
# 9                                 Senescence_gse1786

# %%
data['series'] = data['term'].map(lambda t: t.split('_')[1])
data['tissue'] = data['desc']
data['disease'] = data['term'].map(lambda t: t.split('_')[0])

# %%
data = data[['series', 'tissue', 'disease']]
data[:10]
# Out:
#     series                                tissue  \
# 0  gse4060                         Adrenal gland
# 1  gse5538                        Hepatic Tissue
# 2  gse1462  Muscle - Striated (Skeletal) (MMHCC)
# 3  gse1947                         Sciatic Nerve
# 4  gse1611      CNS - Brain - Cerebellum (MMHCC)
# 5  gse5388                        frontal cortex
# 6  gse9877                      Endothelial cell
# 7  gse1919                     Synovial Membrane
# 8   gse932     CNS - Brain - Hippocampus (MMHCC)
# 9  gse1786  Muscle - Striated (Skeletal) (MMHCC)
#
#                                              disease
# 0                                   Cushing syndrome
# 1                                  Hepatic lipidosis
# 2  Melas - mitochondrial myopathy, encephalopathy...
# 3                        Peripheral motor neuropathy
# 4                                      Down syndrome
# 5                                   Bipolar disorder
# 6                                 Sickle cell anemia
# 7                          Ra (rheumatoid arthritis)
# 8                                   Anxiety disorder
# 9                                         Senescence

# %%
import qgrid
qgrid.show_grid(pd.DataFrame(dict(tissue=data.tissue.value_counts())))
# Out:
# <script type="text/javascript">
# if ($("#dg-css").length == 0){
#     $("head").append([
#         "<link href='/nbextensions/qgridjs/lib/slick.grid.css' rel='stylesheet'>",
#         "<link href='/nbextensions/qgridjs/lib/slick-default-theme.css' rel='stylesheet'>",
#         "<link href='http://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.10.4/css/jquery-ui.min.css' rel='stylesheet'>",
#         "<link id='dg-css' href='/nbextensions/qgridjs/qgrid.css' rel='stylesheet'>"
#     ]);
# }
# </script>
# <div class='q-grid-container'>
# <div id='290df4c0-ae12-4b55-a7b8-2b2d3feb2b88' class='q-grid'></div>
# </div>

# %%
data.tissue.unique().shape
# Out:
# (432,)

# %%
data[data.tissue.map(lambda t: 'MMHCC' in t and 'CNS' in t)]
# Out:
#        series                                tissue  \
# 4     gse1611      CNS - Brain - Cerebellum (MMHCC)
# 8      gse932     CNS - Brain - Hippocampus (MMHCC)
# 11    gse2223                   CNS - Brain (MMHCC)
# 18    gse3075             CNS - Spinal Cord (MMHCC)
# 44    gse3531     CNS - Brain - Hippocampus (MMHCC)
# 75    gse2866      CNS - Brain - Cerebellum (MMHCC)
# 78    gse1481             CNS - Spinal Cord (MMHCC)
# 79    gse2739                   CNS - Brain (MMHCC)
# 81    gse4130    CNS - Brain - Hypothalamus (MMHCC)
# 82   gse18803             CNS - Spinal Cord (MMHCC)
# 85    gse1606                   CNS - Brain (MMHCC)
# 111   gse4290                   CNS - Brain (MMHCC)
# 118     gse63                   CNS - Brain (MMHCC)
# 135    gse833             CNS - Spinal Cord (MMHCC)
# 155   gse2866     CNS - Brain - Hippocampus (MMHCC)
# 172   gse5078     CNS - Brain - Hippocampus (MMHCC)
# 177   gse3253                   CNS - Brain (MMHCC)
# 192   gse4036      CNS - Brain - Cerebellum (MMHCC)
# 206    gse842             CNS - Spinal Cord (MMHCC)
# 211   gse4390             CNS - Spinal Cord (MMHCC)
# 214   gse4236     CNS - Brain - Hippocampus (MMHCC)
# 240   gse2599             CNS - Spinal Cord (MMHCC)
# 241  gse16710             CNS - Spinal Cord (MMHCC)
# 380   gse3131    CNS - Brain - Hypothalamus (MMHCC)
# 628    gse977  CNS - Brain - Olfactory Bulb (MMHCC)
#
#                                                disease
# 4                                        Down syndrome
# 8                                     Anxiety disorder
# 11                                   Oligodendroglioma
# 18                  Spinal muscular atrophy, infantile
# 44                                          Senescence
# 75                      Gamma-hydroxybutyric acidaemia
# 78                          Anterior horn cell disease
# 79                                        Hypertension
# 81                                         Dehydration
# 82                          Neurological pain disorder
# 85                                     Turner syndrome
# 111                                  Oligodendroglioma
# 118                                Cerebral infarction
# 135                Als (amyotrophic lateral sclerosis)
# 155                     Gamma-hydroxybutyric acidaemia
# 172                                         Senescence
# 177  Escherichia coli infection of the central nerv...
# 192                                      Schizophrenia
# 206                            Ms (multiple sclerosis)
# 211                Als (amyotrophic lateral sclerosis)
# 214                                 Status epilepticus
# 240                                 Spinal cord injury
# 241                                 Spinal cord injury
# 380                                        Dehydration
# 628                                  Alexander disease

# %%
data['tissue_cl'] = data['tissue'].map(lambda t: t
                                       .lower()
                                       .replace('mmhcc', '')
                                       .replace('cns', '')
                                       .replace(' - ', ' ')
                                       .replace('(', '')
                                       .replace(')', '')
                                       .replace('tissue', '')
                                       .strip() 
                  )

# %%
qgrid.show_grid(data)
# Out:
# <script type="text/javascript">
# if ($("#dg-css").length == 0){
#     $("head").append([
#         "<link href='/nbextensions/qgridjs/lib/slick.grid.css' rel='stylesheet'>",
#         "<link href='/nbextensions/qgridjs/lib/slick-default-theme.css' rel='stylesheet'>",
#         "<link href='http://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.10.4/css/jquery-ui.min.css' rel='stylesheet'>",
#         "<link id='dg-css' href='/nbextensions/qgridjs/qgrid.css' rel='stylesheet'>"
#     ]);
# }
# </script>
# <div class='q-grid-container'>
# <div id='94e63f6b-d2c5-4908-80c9-a7b949fe2579' class='q-grid'></div>
# </div>

# %%
# ?search_term

# %%
search_term(
           es=es,
           index='tissue_ontology',
           term='breast' 
           )
# Out:
# ['BTO:0000149',
#  'BTO:0001428',
#  'BTO:0001211',
#  'BTO:0005016',
#  'BTO:0000816',
#  'BTO:0000150',
#  'BTO:0000356',
#  'BTO:0002843',
#  'BTO:0002326',
#  'BTO:0001912',
#  'BTO:0000185',
#  'BTO:0004633',
#  'BTO:0002844',
#  'BTO:0000186',
#  'BTO:0002994',
#  'BTO:0002311',
#  'BTO:0004718',
#  'BTO:0005437',
#  'BTO:0000023']

# %%
ontology = read_ontology('../data/geo-annotation/brenda-tissue-ontology.obo')
# Out:
# Read obo graph
# Name:
# Type: DiGraph
# Number of nodes: 5659
# Number of edges: 6430
# Average in degree:   1.1362
# Average out degree:   1.1362

# %%
data['ontology_match'] = data['tissue_cl'].map(lambda t: search_term(
           es=es,
           index='tissue_ontology',
           term=t 
           ))

# %%
data['ontology_match'] = data['ontology_match'].map(collapse_matches(ontology.graph))

# %%
def name(item_id):
    return '{} ({})'.format(ontology_name(item_id), item_id)
def ontology_name(item_id):
    if item_id not in ontology.meta:
        return item_id
    return ontology.meta[item_id].name

# %%
data[['tissue_cl', 'ontology_match']].assign(names=lambda d: d['ontology_match'].map(lambda d: [name(m) for m in d]))
# Out:
#                                              tissue_cl  \
# 0                                        adrenal gland
# 1                                              hepatic
# 2                             muscle striated skeletal
# 3                                        sciatic nerve
# 4                                     brain cerebellum
# 5                                       frontal cortex
# 6                                     endothelial cell
# 7                                    synovial membrane
# 8                                    brain hippocampus
# 9                             muscle striated skeletal
# 10                                          myocardial
# 11                                               brain
# 12                                           epidermis
# 13                                              pleura
# 14                               intestinal epithelium
# 15                                        t lymphocyte
# 16                                         whole blood
# 17                                               liver
# 18                                         spinal cord
# 19                                          macrophage
# 20       leukocyte lymphocyte b-lymphocyte plasma cell
# 21                            muscle striated skeletal
# 22                       leukocyte monocyte macrophage
# 23                                            prostate
# 24                                         lymphoblast
# 25                                                lung
# 26                                               brain
# 27                            muscle striated skeletal
# 28                                              retina
# 29                                       mammary gland
# ..                                                 ...
# 640  skeletal muscle from obese women with polycyst...
# 641                                   mammary arterial
# 642  endometrial   endometrioma  and eutopic endome...
# 643     minor salivary glands early sjogren's syndrome
# 644  minor salivary glands advanced sjogren's syndrome
# 645  minor salivary glands moderate sjogren's syndrome
# 646  induced pluripotent stem cell-derived neurons ...
# 647  induced pluripotent stem cell-derived neurons ...
# 648  percutaneous needle liver biopsies hepatokines...
# 649  percutaneous needle liver biopsies hepatokines...
# 650                                       t lymphocyte
# 651                                        small bowel
# 652                      fibroblast cell lines 3 years
# 653                 peripheral blood mononuclear cells
# 654                                          glomeruli
# 655                                              aorta
# 656                      t lymphocytes heterozygous fh
# 657                        t lymphocytes homozygous fh
# 658                          monocytes heterozygous fh
# 659                            monocytes homozygous fh
# 660                  retina adult cd-1 animals 5 weeks
# 661                             wrist muscles extensor
# 662                               wrist muscles flexor
# 663                                              lungs
# 664                     esophageal squamous epithelium
# 665                                       t lymphocyte
# 666                                               skin
# 667                                      megakaryocyte
# 668                                            hepatic
# 669                                           appendix
#
#                                         ontology_match  \
# 0              [BTO:0000592, BTO:0000049, BTO:0000045]
# 1    [BTO:0000608, BTO:0003513, BTO:0004270, BTO:00...
# 2                                                   []
# 3                                        [BTO:0001221]
# 4                                                   []
# 5                                        [BTO:0000484]
# 6    [BTO:0003247, BTO:0004400, BTO:0004574, BTO:00...
# 7                                        [BTO:0001823]
# 8                                                   []
# 9                                                   []
# 10                                                  []
# 11   [BTO:0005200, BTO:0002515, BTO:0000690, BTO:00...
# 12                                       [BTO:0000404]
# 13                                       [BTO:0001791]
# 14                                       [BTO:0000781]
# 15   [BTO:0000308, BTO:0002417, BTO:0005431, BTO:00...
# 16                                       [BTO:0000089]
# 17   [BTO:0005265, BTO:0002931, BTO:0000608, BTO:00...
# 18                          [BTO:0002777, BTO:0001279]
# 19   [BTO:0000602, BTO:0001034, BTO:0002889, BTO:00...
# 20                                                  []
# 21                                                  []
# 22                                                  []
# 23   [BTO:0005555, BTO:0003972, BTO:0005128, BTO:00...
# 24                          [BTO:0005261, BTO:0001826]
# 25   [BTO:0004078, BTO:0000161, BTO:0002205, BTO:00...
# 26   [BTO:0005200, BTO:0002515, BTO:0000690, BTO:00...
# 27                                                  []
# 28                                       [BTO:0000929]
# 29   [BTO:0004718, BTO:0003568, BTO:0004087, BTO:00...
# ..                                                 ...
# 640                                                 []
# 641                                                 []
# 642                                                 []
# 643                                                 []
# 644                                                 []
# 645                                                 []
# 646                                                 []
# 647                                                 []
# 648                                                 []
# 649                                                 []
# 650  [BTO:0000308, BTO:0002417, BTO:0005431, BTO:00...
# 651                                                 []
# 652                                                 []
# 653                                                 []
# 654                                      [BTO:0002297]
# 655  [BTO:0004674, BTO:0005553, BTO:0000394, BTO:00...
# 656                                                 []
# 657                                                 []
# 658                                                 []
# 659                                                 []
# 660                                                 []
# 661                                                 []
# 662                                                 []
# 663                                                 []
# 664                                      [BTO:0003635]
# 665  [BTO:0000308, BTO:0002417, BTO:0005431, BTO:00...
# 666  [BTO:0003894, BTO:0005082, BTO:0001619, BTO:00...
# 667                                      [BTO:0000843]
# 668  [BTO:0000608, BTO:0003513, BTO:0004270, BTO:00...
# 669                                      [BTO:0000084]
#
#                                                  names
# 0    [adrenal gland cancer cell (BTO:0000592), adre...
# 1    [hepatoma cell (BTO:0000608), hepatic stellate...
# 2                                                   []
# 3                        [sciatic nerve (BTO:0001221)]
# 4                                                   []
# 5                         [frontal lobe (BTO:0000484)]
# 6    [baec cell (BTO:0003247), bpaec cell (BTO:0004...
# 7                             [synovium (BTO:0001823)]
# 8                                                   []
# 9                                                   []
# 10                                                  []
# 11   [brain microvessel endothelial cell (BTO:00052...
# 12                           [epidermis (BTO:0000404)]
# 13                              [pleura (BTO:0001791)]
# 14               [intestinal epithelium (BTO:0000781)]
# 15   [cytotoxic t-lymphocyte cell line (BTO:0000308...
# 16                               [blood (BTO:0000089)]
# 17   [nonparenchymal liver cell (BTO:0005265), live...
# 18   [anterolateral sulcus of medulla oblongata (BT...
# 19   [histiocyte (BTO:0000602), peritoneal macropha...
# 20                                                  []
# 21                                                  []
# 22                                                  []
# 23   [basal prostate epithelium cell (BTO:0005555),...
# 24   [b-lymphoblast cell line (BTO:0005261), t-lymp...
# 25   [non-small cell lung adenocarcinoma cell line ...
# 26   [brain microvessel endothelial cell (BTO:00052...
# 27                                                  []
# 28                       [neural retina (BTO:0000929)]
# 29   [breast lobe (BTO:0004718), mammary gland cell...
# ..                                                 ...
# 640                                                 []
# 641                                                 []
# 642                                                 []
# 643                                                 []
# 644                                                 []
# 645                                                 []
# 646                                                 []
# 647                                                 []
# 648                                                 []
# 649                                                 []
# 650  [cytotoxic t-lymphocyte cell line (BTO:0000308...
# 651                                                 []
# 652                                                 []
# 653                                                 []
# 654           [renal glomerular capsule (BTO:0002297)]
# 655  [ventral aorta (BTO:0004674), aortic intima (B...
# 656                                                 []
# 657                                                 []
# 658                                                 []
# 659                                                 []
# 660                                                 []
# 661                                                 []
# 662                                                 []
# 663                                                 []
# 664     [esophageal squamous epithelium (BTO:0003635)]
# 665  [cytotoxic t-lymphocyte cell line (BTO:0000308...
# 666  [skin carcinoma cell line (BTO:0003894), skin ...
# 667                      [megakaryocyte (BTO:0000843)]
# 668  [hepatoma cell (BTO:0000608), hepatic stellate...
# 669                 [vermiform appendix (BTO:0000084)]
#
# [670 rows x 3 columns]

# %%
(data[data['ontology_match'].map(lambda m: len(m) == 1)].tissue_cl.unique().shape, 
 data[data['ontology_match'].map(lambda m: len(m) == 0)].tissue_cl.unique().shape
 )
# Out:
# ((49,), (293,))
