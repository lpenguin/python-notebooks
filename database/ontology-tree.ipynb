# %%
from elasticsearch import Elasticsearch
es = Elasticsearch()

# %%
import sys
sys.path.append('../')

# %%
# !pwd
# Out:
# /home/ubuntu/python-notebooks/database

# %%
from lib.obo import read_ontology
tissue_ontology = read_ontology('../data/geo-annotation/brenda-tissue-ontology.obo')
# Out:
# Read obo graph
# Name:
# Type: DiGraph
# Number of nodes: 5659
# Number of edges: 6430
# Average in degree:   1.1362
# Average out degree:   1.1362

# %%
def get_doc_counts(index, field, filter_=None):
    body = {
        "size": 0,
        "aggs": {
            "nodes": {
              "terms": {
                "field": field,
                "size": 8000
              }
            }
        }
    }
    
    if filter_:
        body['query'] = {
            "filtered": {
                "filter": filter_
            }
        }
    
    res = es.search(index=index, body=body)
    return dict((r['key'], r['doc_count']) for r in res['aggregations']['nodes']['buckets'])

# %%
tissue_counts = get_doc_counts('samples_dev', 'annotation.tissue_id', {
        "term": {
            "organism": "Homo sapiens"
        }
    })

# %%
import networkx as nx
# ?tissue_ontology.name

# %%
from itertools import chain
def build_tree(ontology, root_node, index, field,  filter_=None):
    counts = get_doc_counts(index, field, filter_)
    def build_node(node_id):
#         print(node_id)
#         print(ontology.graph.successors(node_id))
        descs = nx.descendants(ontology.graph, node_id)
        total_count = sum(
            counts[nid]
            for nid in chain(descs, [node_id])
            if nid in counts
        )
        
        
        if total_count:
            children = [
                build_node(child_node_id)
                for child_node_id in ontology.graph.successors(node_id)
            ]
        else:
            children = []
            
        return {
            'id': node_id,
            'name': ontology.name(node_id),
            'count': total_count,
            'children': children
        }
    return build_node(root_node)

# %%
n = build_tree(tissue_ontology, 
           root_node='BTO:0000000', 
           index='samples_dev', 
           field='annotation.tissue_id', 
           filter_={
              "exists": {
                "field": "annotation.age"
              }
            })

# %%
n['count']
# Out:
# 60950

# %%
n['children']
# Out:
# [{'children': [], 'count': 0, 'id': 'BTO:0001494', 'name': 'fungus'},
#  {'children': [{'children': [],
#     'count': 0,
#     'id': 'BTO:0003809',
#     'name': 'soil'},
#    {'children': [{'children': [],
#       'count': 0,
#       'id': 'BTO:0000311',
#       'name': 'culture filtrate'},
#      {'children': [],
#       'count': 0,
#       'id': 'BTO:0001982',
#       'name': 'chemostat culture'},
#      {'children': [],
#       'count': 0,
#       'id': 'BTO:0000152',
#       'name': 'infected cell'},
#      {'children': [],
#       'count': 0,
#       'id': 'BTO:0004503',
#       'name': 'submerged culture'},
#      {'children': [],
#       'count': 0,
#       'id': 'BTO:0005517',
#       'name': 'lyophilized cell'},
#      {'children': [],
#       'count': 0,
#       'id': 'BTO:0001091',
#       'name': 'axenic culture'},
#      {'children': [],
#       'count': 0,
#       'id': 'BTO:0003916',
#       'name': 'plant culture'},
#      {'children': [], 'count': 0, 'id': 'BTO:0000682', 'name': 'koji culture'},
#      {'children': [],
#       'count': 0,
#       'id': 'BTO:0001900',
#       'name': 'growth phase culture'},
#      {'children': [], 'count': 0, 'id': 'BTO:0003143', 'name': 'coculture'},
#      {'children': [],
#       'count': 0,
#       'id': 'BTO:0000216',
#       'name': 'culture condition'},
#      {'children': [],
#       'count': 0,
#       'id': 'BTO:0000316',
#       'name': 'culture medium'},
#      {'children': [], 'count': 0, 'id': 'BTO:0004304', 'name': 'cell lysate'},
#      {'children': [{'children': [{'children': [],
#           'count': 0,
#           'id': 'BTO:0004117',
#           'name': 'hfk cell'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0002290',
#           'name': 'primary cell line'}],
#         'count': 243,
#         'id': 'BTO:0001413',
#         'name': 'primary cell'}],
#       'count': 243,
#       'id': 'BTO:0001127',
#       'name': 'primary culture'},
#      {'children': [],
#       'count': 0,
#       'id': 'BTO:0000221',
#       'name': 'cell suspension culture'},
#      {'children': [],
#       'count': 0,
#       'id': 'BTO:0005210',
#       'name': 'syntrophic cell culture'},
#      {'children': [],
#       'count': 0,
#       'id': 'BTO:0002276',
#       'name': 'immobilized cell'},
#      {'children': [],
#       'count': 0,
#       'id': 'BTO:0002294',
#       'name': 'solid substrate culture'},
#      {'children': [],
#       'count': 0,
#       'id': 'BTO:0001384',
#       'name': 'tissue culture'},
#      {'children': [],
#       'count': 0,
#       'id': 'BTO:0002217',
#       'name': 'culture supernatant'}],
#     'count': 243,
#     'id': 'BTO:0000214',
#     'name': 'cell culture'},
#    {'children': [], 'count': 0, 'id': 'BTO:0004045', 'name': 'air pouch'},
#    {'children': [],
#     'count': 0,
#     'id': 'BTO:0000278',
#     'name': 'commercial preparation'}],
#   'count': 243,
#   'id': 'BTO:0001490',
#   'name': 'other source'},
#  {'children': [{'children': [{'children': [{'children': [],
#         'count': 0,
#         'id': 'BTO:0005626',
#         'name': 'osteoarticular cell'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0002330',
#         'name': 'lamina propria'},
#        {'children': [{'children': [{'children': [{'children': [],
#               'count': 0,
#               'id': 'BTO:0003742',
#               'name': 'synoviocyte'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0001339',
#               'name': 'synovia'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0003652',
#               'name': 'synovial cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0001824',
#               'name': 'synovial sarcoma cell'}],
#             'count': 105,
#             'id': 'BTO:0001823',
#             'name': 'synovium'}],
#           'count': 105,
#           'id': 'BTO:0000051',
#           'name': 'tendon sheath'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0001507',
#           'name': 'pes anserinus'}],
#         'count': 140,
#         'id': 'BTO:0001356',
#         'name': 'tendon'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0004238',
#         'name': 'interstitial cell'},
#        {'children': [], 'count': 0, 'id': 'BTO:0001686', 'name': 'joint'},
#        {'children': [{'children': [],
#           'count': 0,
#           'id': 'BTO:0001593',
#           'name': 'osteoblast'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0004256',
#           'name': 'long bone'},
#          {'children': [], 'count': 40, 'id': 'BTO:0001284', 'name': 'femur'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0000412',
#           'name': 'epiphyseal growth plate'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0000967',
#           'name': 'osseous plate'},
#          {'children': [{'children': [],
#             'count': 0,
#             'id': 'BTO:0000969',
#             'name': 'osteoclastoma cell'}],
#           'count': 3,
#           'id': 'BTO:0000968',
#           'name': 'osteoclast'},
#          {'children': [], 'count': 22, 'id': 'BTO:0001252', 'name': 'tibia'},
#          {'children': [{'children': [],
#             'count': 0,
#             'id': 'BTO:0001328',
#             'name': 'calvarium'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0004140',
#             'name': 'ethmoid bone'},
#            {'children': [{'children': [],
#               'count': 0,
#               'id': 'BTO:0005216',
#               'name': 'keratocyst'},
#              {'children': [{'children': [],
#                 'count': 0,
#                 'id': 'BTO:0001751',
#                 'name': 'mandibular ramus'}],
#               'count': 1,
#               'id': 'BTO:0001748',
#               'name': 'mandible'}],
#             'count': 1,
#             'id': 'BTO:0001749',
#             'name': 'jaw'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0003674',
#             'name': 'temporomandibular joint'}],
#           'count': 1,
#           'id': 'BTO:0001295',
#           'name': 'cranium'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0000413',
#           'name': 'epiphysis'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0001700',
#           'name': 'cancellous bone'},
#          {'children': [], 'count': 1, 'id': 'BTO:0001218', 'name': 'scapula'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0001022',
#           'name': 'periosteum'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0002343',
#           'name': 'tarsal bone'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0002038',
#           'name': 'osteocyte'},
#          {'children': [], 'count': 2, 'id': 'BTO:0002346', 'name': 'fibula'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0002051',
#           'name': 'preosteoblast'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0005219',
#           'name': 'osteophyte'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0002076',
#           'name': 'osteomalacia cell'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0004384',
#           'name': 'osteoclast stem cell'},
#          {'children': [{'children': [{'children': [{'children': [],
#                 'count': 0,
#                 'id': 'BTO:0003167',
#                 'name': '143b cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0003921',
#                 'name': 'khos cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005358',
#                 'name': 'jarques cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0001951',
#                 'name': 'hos-te85 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005354',
#                 'name': 'd17 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005359',
#                 'name': 'marisco cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0002089',
#                 'name': 'cal-72 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005369',
#                 'name': 'hmpos cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0002576',
#                 'name': 'umr-106 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005399',
#                 'name': 'pos cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0002431',
#                 'name': 'huo-3n1 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0002648',
#                 'name': 'ros-17/2.8 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0003877',
#                 'name': 'g-292 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0004216',
#                 'name': 'sjsa-1 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0003967',
#                 'name': 'osrga cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0001938',
#                 'name': 'u2-os cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0004012',
#                 'name': 'ros cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0002177',
#                 'name': 'pr cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005357',
#                 'name': 'ingles cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0003904',
#                 'name': 'hos cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005363',
#                 'name': 'cos-31 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005356',
#                 'name': 'hughes cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0001596',
#                 'name': 'mg-63 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0002577',
#                 'name': 'umr-108 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005353',
#                 'name': 'abrams cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005355',
#                 'name': 'grey cell'},
#                {'children': [],
#                 'count': 1,
#                 'id': 'BTO:0000971',
#                 'name': 'saos-2 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0003778',
#                 'name': 'saos-alpha2beta1 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0004885',
#                 'name': 'osa-344 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0002054',
#                 'name': 'dunn cell'}],
#               'count': 1,
#               'id': 'BTO:0000407',
#               'name': 'osteosarcoma cell line'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0001574',
#               'name': 'chondrosarcoma cell line'}],
#             'count': 1,
#             'id': 'BTO:0000385',
#             'name': 'bone cancer cell line'}],
#           'count': 1,
#           'id': 'BTO:0000374',
#           'name': 'bone cell line'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0005552',
#           'name': 'vertebral endplate'},
#          {'children': [{'children': [{'children': [{'children': [],
#                 'count': 0,
#                 'id': 'BTO:0003167',
#                 'name': '143b cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0003921',
#                 'name': 'khos cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005358',
#                 'name': 'jarques cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0001951',
#                 'name': 'hos-te85 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005354',
#                 'name': 'd17 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005359',
#                 'name': 'marisco cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0002089',
#                 'name': 'cal-72 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005369',
#                 'name': 'hmpos cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0002576',
#                 'name': 'umr-106 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005399',
#                 'name': 'pos cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0002431',
#                 'name': 'huo-3n1 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0002648',
#                 'name': 'ros-17/2.8 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0003877',
#                 'name': 'g-292 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0004216',
#                 'name': 'sjsa-1 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0003967',
#                 'name': 'osrga cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0001938',
#                 'name': 'u2-os cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0004012',
#                 'name': 'ros cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0002177',
#                 'name': 'pr cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005357',
#                 'name': 'ingles cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0003904',
#                 'name': 'hos cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005363',
#                 'name': 'cos-31 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005356',
#                 'name': 'hughes cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0001596',
#                 'name': 'mg-63 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0002577',
#                 'name': 'umr-108 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005353',
#                 'name': 'abrams cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005355',
#                 'name': 'grey cell'},
#                {'children': [],
#                 'count': 1,
#                 'id': 'BTO:0000971',
#                 'name': 'saos-2 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0003778',
#                 'name': 'saos-alpha2beta1 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0004885',
#                 'name': 'osa-344 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0002054',
#                 'name': 'dunn cell'}],
#               'count': 1,
#               'id': 'BTO:0000407',
#               'name': 'osteosarcoma cell line'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0001574',
#               'name': 'chondrosarcoma cell line'}],
#             'count': 1,
#             'id': 'BTO:0000385',
#             'name': 'bone cancer cell line'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0000969',
#             'name': 'osteoclastoma cell'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0002361',
#             'name': 'osteochondroma cell'},
#            {'children': [{'children': [],
#               'count': 0,
#               'id': 'BTO:0002071',
#               'name': "kaposi's sarcoma cell"},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0003745',
#               'name': 'liposarcoma cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0001214',
#               'name': 'yoshida sarcoma cell'},
#              {'children': [{'children': [{'children': [],
#                   'count': 0,
#                   'id': 'BTO:0003768',
#                   'name': 'a-673 cell'},
#                  {'children': [],
#                   'count': 0,
#                   'id': 'BTO:0003767',
#                   'name': 'a-204 cell'},
#                  {'children': [],
#                   'count': 0,
#                   'id': 'BTO:0005378',
#                   'name': 'rh-1 cell'},
#                  {'children': [],
#                   'count': 1,
#                   'id': 'BTO:0002605',
#                   'name': 'te-671 cell'},
#                  {'children': [],
#                   'count': 0,
#                   'id': 'BTO:0005377',
#                   'name': 'rd cell'},
#                  {'children': [],
#                   'count': 0,
#                   'id': 'BTO:0005382',
#                   'name': 'rh-5 cell'},
#                  {'children': [],
#                   'count': 0,
#                   'id': 'BTO:0005381',
#                   'name': 'rh-4 cell'},
#                  {'children': [],
#                   'count': 0,
#                   'id': 'BTO:0005384',
#                   'name': 'rh-28 cell'},
#                  {'children': [],
#                   'count': 0,
#                   'id': 'BTO:0004529',
#                   'name': 'pa-23 cell'},
#                  {'children': [],
#                   'count': 0,
#                   'id': 'BTO:0005383',
#                   'name': 'rh-3 cell'},
#                  {'children': [],
#                   'count': 0,
#                   'id': 'BTO:0005380',
#                   'name': 'rh-18 cell'},
#                  {'children': [],
#                   'count': 0,
#                   'id': 'BTO:0005379',
#                   'name': 'rh-30 cell'}],
#                 'count': 1,
#                 'id': 'BTO:0002267',
#                 'name': 'rhabdomyosarcoma cell line'}],
#               'count': 1,
#               'id': 'BTO:0001802',
#               'name': 'rhabdomyosarcoma cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0001824',
#               'name': 'synovial sarcoma cell'},
#              {'children': [{'children': [],
#                 'count': 0,
#                 'id': 'BTO:0001915',
#                 'name': 'm5076 cell'},
#                {'children': [{'children': [],
#                   'count': 0,
#                   'id': 'BTO:0003768',
#                   'name': 'a-673 cell'},
#                  {'children': [],
#                   'count': 0,
#                   'id': 'BTO:0003767',
#                   'name': 'a-204 cell'},
#                  {'children': [],
#                   'count': 0,
#                   'id': 'BTO:0005378',
#                   'name': 'rh-1 cell'},
#                  {'children': [],
#                   'count': 1,
#                   'id': 'BTO:0002605',
#                   'name': 'te-671 cell'},
#                  {'children': [],
#                   'count': 0,
#                   'id': 'BTO:0005377',
#                   'name': 'rd cell'},
#                  {'children': [],
#                   'count': 0,
#                   'id': 'BTO:0005382',
#                   'name': 'rh-5 cell'},
#                  {'children': [],
#                   'count': 0,
#                   'id': 'BTO:0005381',
#                   'name': 'rh-4 cell'},
#                  {'children': [],
#                   'count': 0,
#                   'id': 'BTO:0005384',
#                   'name': 'rh-28 cell'},
#                  {'children': [],
#                   'count': 0,
#                   'id': 'BTO:0004529',
#                   'name': 'pa-23 cell'},
#                  {'children': [],
#                   'count': 0,
#                   'id': 'BTO:0005383',
#                   'name': 'rh-3 cell'},
#                  {'children': [],
#                   'count': 0,
#                   'id': 'BTO:0005380',
#                   'name': 'rh-18 cell'},
#                  {'children': [],
#                   'count': 0,
#                   'id': 'BTO:0005379',
#                   'name': 'rh-30 cell'}],
#                 'count': 1,
#                 'id': 'BTO:0002267',
#                 'name': 'rhabdomyosarcoma cell line'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005229',
#                 'name': 'xc-v cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005227',
#                 'name': 'xc cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0002638',
#                 'name': 'hs 925.t cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0001197',
#                 'name': 's-180 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0002595',
#                 'name': 'leiomyosarcoma cell line'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0001210',
#                 'name': 'sgs cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0003744',
#                 'name': 'liposarcoma cell line'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0004785',
#                 'name': "ewing's sarcoma family tumor cell line"},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0000460',
#                 'name': 'fibrosarcoma cell line'}],
#               'count': 1,
#               'id': 'BTO:0000400',
#               'name': 'sarcoma cell line'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0000970',
#               'name': 'osteosarcoma cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0000250',
#               'name': 'chondrosarcoma cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0001212',
#               'name': 'rous sarcoma cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0000459',
#               'name': 'fibrosarcoma cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0001631',
#               'name': 'leiomyosarcoma cell'},
#              {'children': [],
#               'count': 4,
#               'id': 'BTO:0002513',
#               'name': "ewing's sarcoma cell"}],
#             'count': 12,
#             'id': 'BTO:0001207',
#             'name': 'sarcoma cell'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0000006',
#             'name': 'osteoblastoma cell'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0004255',
#             'name': "ewing's family tumor cell"}],
#           'count': 13,
#           'id': 'BTO:0000372',
#           'name': 'bone cancer cell'},
#          {'children': [],
#           'count': 1,
#           'id': 'BTO:0002347',
#           'name': 'metatarsal bone'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0002157',
#           'name': 'endochondral bone'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0004496',
#           'name': 'preosteoclast'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0004592',
#           'name': 'bone matrix'},
#          {'children': [], 'count': 0, 'id': 'BTO:0001302', 'name': 'sternum'}],
#         'count': 136,
#         'id': 'BTO:0000140',
#         'name': 'bone'},
#        {'children': [], 'count': 0, 'id': 'BTO:0000830', 'name': 'mast cell'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0004568',
#         'name': 'supportive connective tissue'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0003257',
#         'name': 'granulation tissue'},
#        {'children': [], 'count': 0, 'id': 'BTO:0000305', 'name': 'crypt'},
#        {'children': [{'children': [{'children': [],
#             'count': 0,
#             'id': 'BTO:0003742',
#             'name': 'synoviocyte'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0001339',
#             'name': 'synovia'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0003652',
#             'name': 'synovial cell'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0001824',
#             'name': 'synovial sarcoma cell'}],
#           'count': 105,
#           'id': 'BTO:0001823',
#           'name': 'synovium'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0003702',
#           'name': 'rheumatoid arthritis disease specific synovial tissue'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0001336',
#           'name': 'synovial fibroblast'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0003436',
#           'name': 'synovial cell line'}],
#         'count': 124,
#         'id': 'BTO:0001338',
#         'name': 'synovial tissue'},
#        {'children': [], 'count': 17, 'id': 'BTO:0002930', 'name': 'fascia'},
#        {'children': [{'children': [],
#           'count': 0,
#           'id': 'BTO:0001628',
#           'name': 'epiglottis'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0003607',
#           'name': 'chondroblast'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0000248',
#           'name': 'chondroclast'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0002365',
#           'name': 'chondroblastoma cell'},
#          {'children': [{'children': [],
#             'count': 0,
#             'id': 'BTO:0002071',
#             'name': "kaposi's sarcoma cell"},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0003745',
#             'name': 'liposarcoma cell'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0001214',
#             'name': 'yoshida sarcoma cell'},
#            {'children': [{'children': [{'children': [],
#                 'count': 0,
#                 'id': 'BTO:0003768',
#                 'name': 'a-673 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0003767',
#                 'name': 'a-204 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005378',
#                 'name': 'rh-1 cell'},
#                {'children': [],
#                 'count': 1,
#                 'id': 'BTO:0002605',
#                 'name': 'te-671 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005377',
#                 'name': 'rd cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005382',
#                 'name': 'rh-5 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005381',
#                 'name': 'rh-4 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005384',
#                 'name': 'rh-28 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0004529',
#                 'name': 'pa-23 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005383',
#                 'name': 'rh-3 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005380',
#                 'name': 'rh-18 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005379',
#                 'name': 'rh-30 cell'}],
#               'count': 1,
#               'id': 'BTO:0002267',
#               'name': 'rhabdomyosarcoma cell line'}],
#             'count': 1,
#             'id': 'BTO:0001802',
#             'name': 'rhabdomyosarcoma cell'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0001824',
#             'name': 'synovial sarcoma cell'},
#            {'children': [{'children': [],
#               'count': 0,
#               'id': 'BTO:0001915',
#               'name': 'm5076 cell'},
#              {'children': [{'children': [],
#                 'count': 0,
#                 'id': 'BTO:0003768',
#                 'name': 'a-673 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0003767',
#                 'name': 'a-204 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005378',
#                 'name': 'rh-1 cell'},
#                {'children': [],
#                 'count': 1,
#                 'id': 'BTO:0002605',
#                 'name': 'te-671 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005377',
#                 'name': 'rd cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005382',
#                 'name': 'rh-5 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005381',
#                 'name': 'rh-4 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005384',
#                 'name': 'rh-28 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0004529',
#                 'name': 'pa-23 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005383',
#                 'name': 'rh-3 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005380',
#                 'name': 'rh-18 cell'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005379',
#                 'name': 'rh-30 cell'}],
#               'count': 1,
#               'id': 'BTO:0002267',
#               'name': 'rhabdomyosarcoma cell line'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0005229',
#               'name': 'xc-v cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0005227',
#               'name': 'xc cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0002638',
#               'name': 'hs 925.t cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0001197',
#               'name': 's-180 cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0002595',
#               'name': 'leiomyosarcoma cell line'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0001210',
#               'name': 'sgs cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0003744',
#               'name': 'liposarcoma cell line'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0004785',
#               'name': "ewing's sarcoma family tumor cell line"},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0000460',
#               'name': 'fibrosarcoma cell line'}],
#             'count': 1,
#             'id': 'BTO:0000400',
#             'name': 'sarcoma cell line'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0000970',
#             'name': 'osteosarcoma cell'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0000250',
#             'name': 'chondrosarcoma cell'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0001212',
#             'name': 'rous sarcoma cell'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0000459',
#             'name': 'fibrosarcoma cell'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0001631',
#             'name': 'leiomyosarcoma cell'},
#            {'children': [],
#             'count': 4,
#             'id': 'BTO:0002513',
#             'name': "ewing's sarcoma cell"}],
#           'count': 12,
#           'id': 'BTO:0001207',
#           'name': 'sarcoma cell'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0000207',
#           'name': 'tibial cartilage'},
#          {'children': [], 'count': 0, 'id': 'BTO:0001592', 'name': 'meniscus'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0003627',
#           'name': 'annulus fibrosus'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0000249',
#           'name': 'chondrocyte'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0000412',
#           'name': 'epiphyseal growth plate'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0005185',
#           'name': 'chondroma cell'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0001721',
#           'name': 'sternal cartilage'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0001572',
#           'name': 'articular cartilage'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0005089',
#           'name': 'perichondrium'}],
#         'count': 13,
#         'id': 'BTO:0000206',
#         'name': 'cartilage'},
#        {'children': [{'children': [],
#           'count': 0,
#           'id': 'BTO:0004043',
#           'name': 'intramuscular adipose tissue'},
#          {'children': [],
#           'count': 12,
#           'id': 'BTO:0004041',
#           'name': 'abdominal adipose tissue'},
#          {'children': [], 'count': 0, 'id': 'BTO:0000442', 'name': 'fat body'},
#          {'children': [{'children': [{'children': [],
#               'count': 0,
#               'id': 'BTO:0001107',
#               'name': 'preadipocyte'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0003452',
#               'name': 'adipocyte cell line'}],
#             'count': 30,
#             'id': 'BTO:0000443',
#             'name': 'adipocyte'}],
#           'count': 30,
#           'id': 'BTO:0001456',
#           'name': 'white adipose tissue'},
#          {'children': [],
#           'count': 79,
#           'id': 'BTO:0004042',
#           'name': 'subcutaneous adipose tissue'},
#          {'children': [{'children': [{'children': [],
#               'count': 0,
#               'id': 'BTO:0001107',
#               'name': 'preadipocyte'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0003452',
#               'name': 'adipocyte cell line'}],
#             'count': 30,
#             'id': 'BTO:0000443',
#             'name': 'adipocyte'}],
#           'count': 30,
#           'id': 'BTO:0000156',
#           'name': 'brown adipose tissue'},
#          {'children': [{'children': [{'children': [],
#               'count': 0,
#               'id': 'BTO:0001107',
#               'name': 'preadipocyte'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0003452',
#               'name': 'adipocyte cell line'}],
#             'count': 30,
#             'id': 'BTO:0000443',
#             'name': 'adipocyte'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0005628',
#             'name': 'parametrial fat pad'}],
#           'count': 30,
#           'id': 'BTO:0000444',
#           'name': 'fat pad'}],
#         'count': 432,
#         'id': 'BTO:0001487',
#         'name': 'adipose tissue'},
#        {'children': [], 'count': 0, 'id': 'BTO:0003154', 'name': 'epineurium'},
#        {'children': [{'children': [],
#           'count': 0,
#           'id': 'BTO:0004752',
#           'name': 'adipose-derived stromal cell'},
#          {'children': [],
#           'count': 16,
#           'id': 'BTO:0003697',
#           'name': 'endometrial stromal cell'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0003972',
#           'name': 'prostate gland stromal cell'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0003952',
#           'name': 'mesenchymal stromal cell'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0004122',
#           'name': 'bone marrow stromal cell'}],
#         'count': 16,
#         'id': 'BTO:0002064',
#         'name': 'stromal cell'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0005627',
#         'name': 'parametrium'},
#        {'children': [], 'count': 0, 'id': 'BTO:0002501', 'name': 'trabecula'},
#        {'children': [], 'count': 0, 'id': 'BTO:0000829', 'name': 'marrow'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0004525',
#         'name': 'subcutaneous tissue'},
#        {'children': [{'children': [],
#           'count': 0,
#           'id': 'BTO:0004725',
#           'name': 'embryonic fibroblast'},
#          {'children': [{'children': [{'children': [],
#               'count': 0,
#               'id': 'BTO:0004931',
#               'name': 'npd-1 cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0004640',
#               'name': 'fd-2 cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0005133',
#               'name': 'ccd-986sk cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0003842',
#               'name': 'gm02037 cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0003591',
#               'name': 'gm00637 cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0005285',
#               'name': 'npd-2 cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0004161',
#               'name': 'malme-3 cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0002245',
#               'name': 'foreskin fibroblast cell line'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0004971',
#               'name': '1br3.g cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0003185',
#               'name': 'nhdf cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0005012',
#               'name': '46br.1g1 cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0004460',
#               'name': 'fd-1 cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0004753',
#               'name': 'xp-v xp30ro cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0003755',
#               'name': 'stf1-169 cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0003589',
#               'name': 'gm08505 cell'},
#              {'children': [],
#               'count': 2,
#               'id': 'BTO:0003590',
#               'name': 'gm01492 cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0003254',
#               'name': 'dpk-skdf-h cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0003754',
#               'name': 'bre-169 cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0003442',
#               'name': 'ccd-43sk cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0004314',
#               'name': 'gm16088 cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0005290',
#               'name': 'te 353.sk cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0003592',
#               'name': 'gm00037 cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0004321',
#               'name': '2bn cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0004313',
#               'name': 'gm16096 cell'}],
#             'count': 2,
#             'id': 'BTO:0001619',
#             'name': 'skin fibroblast cell line'},
#            {'children': [],
#             'count': 36,
#             'id': 'BTO:0004419',
#             'name': 'dermal fibroblast'}],
#           'count': 159,
#           'id': 'BTO:0001255',
#           'name': 'skin fibroblast'},
#          {'children': [{'children': [],
#             'count': 0,
#             'id': 'BTO:0005472',
#             'name': 'rtg-2 cell'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0000331',
#             'name': 'l-929 cell'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0003293',
#             'name': 'rat-1 cell'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0001896',
#             'name': 'idh4 cell'},
#            {'children': [{'children': [],
#               'count': 0,
#               'id': 'BTO:0004931',
#               'name': 'npd-1 cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0004640',
#               'name': 'fd-2 cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0005133',
#               'name': 'ccd-986sk cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0003842',
#               'name': 'gm02037 cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0003591',
#               'name': 'gm00637 cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0005285',
#               'name': 'npd-2 cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0004161',
#               'name': 'malme-3 cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0002245',
#               'name': 'foreskin fibroblast cell line'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0004971',
#               'name': '1br3.g cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0003185',
#               'name': 'nhdf cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0005012',
#               'name': '46br.1g1 cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0004460',
#               'name': 'fd-1 cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0004753',
#               'name': 'xp-v xp30ro cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0003755',
#               'name': 'stf1-169 cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0003589',
#               'name': 'gm08505 cell'},
#              {'children': [],
#               'count': 2,
#               'id': 'BTO:0003590',
#               'name': 'gm01492 cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0003254',
#               'name': 'dpk-skdf-h cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0003754',
#               'name': 'bre-169 cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0003442',
#               'name': 'ccd-43sk cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0004314',
#               'name': 'gm16088 cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0005290',
#               'name': 'te 353.sk cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0003592',
#               'name': 'gm00037 cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0004321',
#               'name': '2bn cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0004313',
#               'name': 'gm16096 cell'}],
#             'count': 2,
#             'id': 'BTO:0001619',
#             'name': 'skin fibroblast cell line'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0004166',
#             'name': 'myofibroblast cell line'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0002749',
#             'name': 'hs-74 cell'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0001867',
#             'name': 'nr-6 cell'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0005270',
#             'name': 'haoaf cell'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0001958',
#             'name': 'embryonic fibroblast cell line'}],
#           'count': 2,
#           'id': 'BTO:0000453',
#           'name': 'fibroblast cell line'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0001336',
#           'name': 'synovial fibroblast'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0004138',
#           'name': 'gingival fibroblast'},
#          {'children': [], 'count': 0, 'id': 'BTO:0000616', 'name': 'i-cell'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0003093',
#           'name': 'cardiofibroblast'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0005414',
#           'name': 'fibrocarcinoma cell'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0001622',
#           'name': 'fibroblastoma cell'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0005640',
#           'name': 'aortic adventitial fibroblast'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0001946',
#           'name': 'myofibroblast'},
#          {'children': [{'children': [],
#             'count': 0,
#             'id': 'BTO:0000161',
#             'name': 'lung fibroblast cell line'}],
#           'count': 11,
#           'id': 'BTO:0000764',
#           'name': 'lung fibroblast'}],
#         'count': 318,
#         'id': 'BTO:0000452',
#         'name': 'fibroblast'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0002853',
#         'name': 'theca folliculi'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0003153',
#         'name': 'perineurium'}],
#       'count': 1079,
#       'id': 'BTO:0000421',
#       'name': 'connective tissue'},
#      {'children': [{'children': [{'children': [{'children': [{'children': [],
#               'count': 0,
#               'id': 'BTO:0003736',
#               'name': 'thyroid epithelial cell'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0004579',
#               'name': 'parenchyma of thyroid gland'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0002617',
#               'name': 'thyroid nodule'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0001876',
#               'name': 'thyroid cell line'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0000997',
#               'name': 'parathyroid gland'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0004708',
#               'name': 'thyroid follicle'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0000196',
# ...
#                   'name': 'walker carcinoma 256 cell'},
#                  {'children': [],
#                   'count': 0,
#                   'id': 'BTO:0002844',
#                   'name': 'breast invasive ductal carcinoma cell'},
#                  {'children': [],
#                   'count': 0,
#                   'id': 'BTO:0000186',
#                   'name': 'lobular carcinoma cell'},
#                  {'children': [],
#                   'count': 0,
#                   'id': 'BTO:0005016',
#                   'name': 'breast hyperplasia cell'},
#                  {'children': [],
#                   'count': 0,
#                   'id': 'BTO:0002843',
#                   'name': 'breast fibroadenoma cell'},
#                  {'children': [],
#                   'count': 0,
#                   'id': 'BTO:0000190',
#                   'name': 'ehrlich tumor carcinoma cell'}],
#                 'count': 278,
#                 'id': 'BTO:0000150',
#                 'name': 'breast cancer cell'}],
#               'count': 6128,
#               'id': 'BTO:0000149',
#               'name': 'breast'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0001786',
#               'name': 'pheromone gland'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0003119',
#               'name': 'clitoral gland'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0000054',
#               'name': 'albumen gland'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0000558',
#               'name': 'hatching gland'},
#              {'children': [],
#               'count': 0,
#               'id': 'BTO:0002370',
#               'name': 'colleterial gland'}],
#             'count': 6795,
#             'id': 'BTO:0000254',
#             'name': 'female reproductive gland'}],
#           'count': 7197,
#           'id': 'BTO:0000083',
#           'name': 'female reproductive system'}],
#         'count': 9260,
#         'id': 'BTO:0000081',
#         'name': 'reproductive system'}],
#       'count': 9955,
#       'id': 'BTO:0003091',
#       'name': 'urogenital system'}],
#     'count': 60950,
#     'id': 'BTO:0001489',
#     'name': 'whole body'}],
#   'count': 60950,
#   'id': 'BTO:0000042',
#   'name': 'animal'},
#  {'children': [{'children': [],
#     'count': 0,
#     'id': 'BTO:0000425',
#     'name': 'erythrocytic stage'},
#    {'children': [], 'count': 0, 'id': 'BTO:0002168', 'name': 'juvenile'},
#    {'children': [],
#     'count': 0,
#     'id': 'BTO:0002007',
#     'name': 'aggregation stage'},
#    {'children': [], 'count': 0, 'id': 'BTO:0002503', 'name': 'protozoan form'},
#    {'children': [], 'count': 0, 'id': 'BTO:0000109', 'name': 'bacteroid'},
#    {'children': [], 'count': 0, 'id': 'BTO:0002743', 'name': 'schistosomulum'},
#    {'children': [], 'count': 0, 'id': 'BTO:0001965', 'name': 'carcass'},
#    {'children': [], 'count': 0, 'id': 'BTO:0003367', 'name': 'daphnid'},
#    {'children': [], 'count': 0, 'id': 'BTO:0001762', 'name': 'neonate'},
#    {'children': [], 'count': 0, 'id': 'BTO:0002690', 'name': 'biofilm'},
#    {'children': [],
#     'count': 0,
#     'id': 'BTO:0000569',
#     'name': 'exoerythrocytic stage'},
#    {'children': [], 'count': 0, 'id': 'BTO:0004377', 'name': 'pup'},
#    {'children': [], 'count': 0, 'id': 'BTO:0002655', 'name': 'postlarva'},
#    {'children': [{'children': [],
#       'count': 0,
#       'id': 'BTO:0001268',
#       'name': 'somatic cell'},
#      {'children': [],
#       'count': 0,
#       'id': 'BTO:0003413',
#       'name': 'encysting cell'},
#      {'children': [], 'count': 0, 'id': 'BTO:0003280', 'name': 'sessile cell'},
#      {'children': [], 'count': 0, 'id': 'BTO:0002312', 'name': 'mature cell'},
#      {'children': [],
#       'count': 0,
#       'id': 'BTO:0002315',
#       'name': 'supporting cell'},
#      {'children': [], 'count': 0, 'id': 'BTO:0002264', 'name': 'dried cell'},
#      {'children': [],
#       'count': 0,
#       'id': 'BTO:0002313',
#       'name': 'immature cell'},
#      {'children': [], 'count': 0, 'id': 'BTO:0003651', 'name': 'spindle cell'},
#      {'children': [],
#       'count': 0,
#       'id': 'BTO:0003281',
#       'name': 'planktonic cell'},
#      {'children': [],
#       'count': 0,
#       'id': 'BTO:0002314',
#       'name': 'satellite cell'},
#      {'children': [],
#       'count': 0,
#       'id': 'BTO:0001434',
#       'name': 'vegetative cell'},
#      {'children': [], 'count': 0, 'id': 'BTO:0001170', 'name': 'resting cell'},
#      {'children': [],
#       'count': 0,
#       'id': 'BTO:0002316',
#       'name': 'stellate cell'},
#      {'children': [{'children': [],
#         'count': 0,
#         'id': 'BTO:0004117',
#         'name': 'hfk cell'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0002290',
#         'name': 'primary cell line'}],
#       'count': 243,
#       'id': 'BTO:0001413',
#       'name': 'primary cell'},
#      {'children': [],
#       'count': 0,
#       'id': 'BTO:0001478',
#       'name': 'zygotene cell'}],
#     'count': 243,
#     'id': 'BTO:0002322',
#     'name': 'cell property'},
#    {'children': [], 'count': 0, 'id': 'BTO:0002256', 'name': 'heterotroph'},
#    {'children': [],
#     'count': 0,
#     'id': 'BTO:0003670',
#     'name': 'microfilarial stage'},
#    {'children': [], 'count': 0, 'id': 'BTO:0001171', 'name': 'spore'},
#    {'children': [], 'count': 0, 'id': 'BTO:0000090', 'name': 'ascidian'},
#    {'children': [],
#     'count': 0,
#     'id': 'BTO:0001551',
#     'name': 'free-living state'},
#    {'children': [], 'count': 0, 'id': 'BTO:0004769', 'name': 'teratocyte'},
#    {'children': [], 'count': 0, 'id': 'BTO:0002258', 'name': 'autotroph'},
#    {'children': [], 'count': 0, 'id': 'BTO:0004586', 'name': 'alevin'},
#    {'children': [], 'count': 0, 'id': 'BTO:0001043', 'name': 'adult'},
#    {'children': [],
#     'count': 0,
#     'id': 'BTO:0001172',
#     'name': 'reticulate body'},
#    {'children': [], 'count': 0, 'id': 'BTO:0001512', 'name': 'imago'},
#    {'children': [],
#     'count': 0,
#     'id': 'BTO:0000377',
#     'name': 'elementary body'},
#    {'children': [{'children': [],
#       'count': 0,
#       'id': 'BTO:0004800',
#       'name': 'amnioserosa'},
#      {'children': [], 'count': 0, 'id': 'BTO:0003834', 'name': 'conceptus'},
#      {'children': [{'children': [],
#         'count': 0,
#         'id': 'BTO:0001785',
#         'name': 'branchial arch'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0004674',
#         'name': 'ventral aorta'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0001542',
#         'name': 'mesonephron'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0001138',
#         'name': 'somatic embryo'},
#        {'children': [], 'count': 0, 'id': 'BTO:0004724', 'name': 'animal cap'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0004726',
#         'name': 'embryonic brain'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0001763',
#         'name': 'neural arch'},
#        {'children': [], 'count': 0, 'id': 'BTO:0001541', 'name': 'pronephros'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0000558',
#         'name': 'hatching gland'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0004385',
#         'name': 'cardinal vein'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0005511',
#         'name': 'embryonic carcinoma cell'},
#        {'children': [], 'count': 0, 'id': 'BTO:0001766', 'name': 'neurula'},
#        {'children': [], 'count': 0, 'id': 'BTO:0000222', 'name': 'myoblast'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0004673',
#         'name': 'dorsal aorta'},
#        {'children': [], 'count': 0, 'id': 'BTO:0000930', 'name': 'neuroblast'},
#        {'children': [], 'count': 0, 'id': 'BTO:0001768', 'name': 'notochord'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0001241',
#         'name': 'shell gland'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0001383',
#         'name': 'alveolar bone'},
#        {'children': [], 'count': 0, 'id': 'BTO:0003882', 'name': 'blastocyte'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0001086',
#         'name': 'embryonic stem cell'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0004024',
#         'name': 'neural cord'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0003217',
#         'name': 'melanoblast'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0004725',
#         'name': 'embryonic fibroblast'},
#        {'children': [], 'count': 0, 'id': 'BTO:0001639', 'name': 'bud'},
#        {'children': [{'children': [{'children': [],
#             'count': 92,
#             'id': 'BTO:0000646',
#             'name': 'left colon'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0005251',
#             'name': 'ink sac'}],
#           'count': 92,
#           'id': 'BTO:0000510',
#           'name': 'hindgut'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0000349',
#           'name': 'gut cavity'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0000956',
#           'name': 'gut epithelium'},
#          {'children': [{'children': [],
#             'count': 0,
#             'id': 'BTO:0000597',
#             'name': 'hepatopancreas'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0005053',
#             'name': 'midgut epithelium'},
#            {'children': [{'children': [],
#               'count': 0,
#               'id': 'BTO:0001137',
#               'name': 'right colon mucosa'}],
#             'count': 45,
#             'id': 'BTO:0000649',
#             'name': 'right colon'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0000076',
#             'name': 'anterior midgut'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0004630',
#             'name': 'middle midgut'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0000077',
#             'name': 'posterior midgut'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0002145',
#             'name': 'midgut cell line'}],
#           'count': 45,
#           'id': 'BTO:0000863',
#           'name': 'midgut'},
#          {'children': [], 'count': 0, 'id': 'BTO:0000547', 'name': 'gut wall'},
#          {'children': [], 'count': 0, 'id': 'BTO:0000507', 'name': 'foregut'}],
#         'count': 137,
#         'id': 'BTO:0000545',
#         'name': 'gut'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0000669',
#         'name': 'embryonic cell line'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0000381',
#         'name': 'embryonic blood'},
#        {'children': [], 'count': 0, 'id': 'BTO:0005351', 'name': 'optic cup'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0003570',
#         'name': 'feather bud'},
#        {'children': [{'children': [],
#           'count': 0,
#           'id': 'BTO:0003953',
#           'name': 'endomesoderm'},
#          {'children': [{'children': [{'children': [],
#               'count': 0,
#               'id': 'BTO:0001708',
#               'name': 'coelomic fluid'},
#              {'children': [{'children': [{'children': [],
#                   'count': 0,
#                   'id': 'BTO:0002424',
#                   'name': 'mesothelioma cell line'},
#                  {'children': [],
#                   'count': 0,
#                   'id': 'BTO:0005119',
#                   'name': 'pleural mesothelioma cell'}],
#                 'count': 2,
#                 'id': 'BTO:0002423',
#                 'name': 'mesothelioma cell'}],
#               'count': 2,
#               'id': 'BTO:0002422',
#               'name': 'mesothelium'}],
#             'count': 2,
#             'id': 'BTO:0001707',
#             'name': 'coelom'},
#            {'children': [{'children': [{'children': [],
#                 'count': 0,
#                 'id': 'BTO:0002424',
#                 'name': 'mesothelioma cell line'},
#                {'children': [],
#                 'count': 0,
#                 'id': 'BTO:0005119',
#                 'name': 'pleural mesothelioma cell'}],
#               'count': 2,
#               'id': 'BTO:0002423',
#               'name': 'mesothelioma cell'}],
#             'count': 2,
#             'id': 'BTO:0002422',
#             'name': 'mesothelium'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0001393',
#             'name': 'mesenchyme'},
#            {'children': [], 'count': 0, 'id': 'BTO:0001558', 'name': 'somite'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0001402',
#             'name': 'urogenital ridge'},
#            {'children': [],
#             'count': 0,
#             'id': 'BTO:0004705',
#             'name': 'connecting stalk'}],
#           'count': 2,
#           'id': 'BTO:0000839',
#           'name': 'mesoderm'},
#          {'children': [], 'count': 0, 'id': 'BTO:0000315', 'name': 'ectoderm'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0000800',
#           'name': 'endoderm'}],
#         'count': 2,
#         'id': 'BTO:0000556',
#         'name': 'germ layer'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0005565',
#         'name': 'embryonic tracheal system'}],
#       'count': 139,
#       'id': 'BTO:0000379',
#       'name': 'embryo'},
#      {'children': [{'children': [],
#         'count': 0,
#         'id': 'BTO:0000448',
#         'name': 'fetal serum'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0002813',
#         'name': 'gubernaculum testis'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0001242',
#         'name': 'fetal cell line'},
#        {'children': [], 'count': 0, 'id': 'BTO:0000838', 'name': 'meconium'},
#        {'children': [{'children': [],
#           'count': 0,
#           'id': 'BTO:0001975',
#           'name': 'placental cell line'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0005404',
#           'name': 'labyrinthine zone'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0005401',
#           'name': 'junctional zone'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0004196',
#           'name': 'placental membrane'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0005362',
#           'name': 'trophoblast giant cell'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0003678',
#           'name': 'placental disc'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0001415',
#           'name': 'umbilical cord'},
#          {'children': [],
#           'count': 0,
#           'id': 'BTO:0003677',
#           'name': 'chorion frondosum'}],
#         'count': 2,
#         'id': 'BTO:0001078',
#         'name': 'placenta'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0000473',
#         'name': 'fetal membrane'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0001415',
#         'name': 'umbilical cord'},
#        {'children': [],
#         'count': 0,
#         'id': 'BTO:0001351',
#         'name': 'vomeronasal nerve'}],
#       'count': 2,
#       'id': 'BTO:0000449',
#       'name': 'fetus'},
#      {'children': [],
#       'count': 0,
#       'id': 'BTO:0003360',
#       'name': 'extraembryonic tissue'},
#      {'children': [], 'count': 0, 'id': 'BTO:0001886', 'name': 'primordium'},
#      {'children': [], 'count': 0, 'id': 'BTO:0001638', 'name': 'blastema'},
#      {'children': [], 'count': 0, 'id': 'BTO:0000514', 'name': 'germ'},
#      {'children': [], 'count': 0, 'id': 'BTO:0000707', 'name': 'larva'},
#      {'children': [], 'count': 0, 'id': 'BTO:0001143', 'name': 'pupa'},
#      {'children': [],
#       'count': 0,
#       'id': 'BTO:0003737',
#       'name': 'tailbud stage'},
#      {'children': [], 'count': 0, 'id': 'BTO:0000854', 'name': 'zygote'}],
#     'count': 141,
#     'id': 'BTO:0000174',
#     'name': 'embryonic structure'}],
#   'count': 384,
#   'id': 'BTO:0000284',
#   'name': 'organism form'},
#  {'children': [], 'count': 0, 'id': 'BTO:0001481', 'name': 'plant'}]

# %%
import json
len(json.dumps(n))
# Out:
# 56133
